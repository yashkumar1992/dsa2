# %%
### Install Requirement
# !pip3 install lightgbm
# Out:
# Collecting lightgbm
#   Using cached https://files.pythonhosted.org/packages/77/0f/5157e6b153b3d4a70dc5fbe2ab6f209604197590f387f03177b7a249ac60/lightgbm-2.2.3-py2.py3-none-manylinux1_x86_64.whl
# Collecting scikit-learn (from lightgbm)
#   Using cached https://files.pythonhosted.org/packages/a0/c5/d2238762d780dde84a20b8c761f563fe882b88c5a5fb03c056547c442a19/scikit_learn-0.21.3-cp36-cp36m-manylinux1_x86_64.whl
# Collecting scipy (from lightgbm)
#   Using cached https://files.pythonhosted.org/packages/29/50/a552a5aff252ae915f522e44642bb49a7b7b31677f9580cfd11bcc869976/scipy-1.3.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting numpy (from lightgbm)
#   Using cached https://files.pythonhosted.org/packages/e5/e6/c3fdc53aed9fa19d6ff3abf97dfad768ae3afce1b7431f7500000816bda5/numpy-1.17.2-cp36-cp36m-manylinux1_x86_64.whl
# Collecting joblib>=0.11 (from scikit-learn->lightgbm)
#   Using cached https://files.pythonhosted.org/packages/cd/c1/50a758e8247561e58cb87305b1e90b171b8c767b15b12a1734001f41d356/joblib-0.13.2-py2.py3-none-any.whl
# Installing collected packages: numpy, scipy, joblib, scikit-learn, lightgbm
# Successfully installed joblib-0.13.2 lightgbm-2.2.3 numpy-1.17.2 scikit-learn-0.21.3 scipy-1.3.1

# %%
# %load_ext autoreload
# %autoreload
# %matplotlib inline
# %config IPCompleter.greedy=True

import gc
import os
import logging
from datetime import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns

import lightgbm as lgb
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold, KFold

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC



warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# %autoreload
# %matplotlib inline


import gc
import os
import logging
from datetime import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns

import lightgbm as lgb
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt


import sklearn as sk
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold, KFold

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC



warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import

# %%
try :
   import dsa.da.util_model as util_model
   import dsa.da.util_feature as util_feature
   import dsa.da.util_plot as util_plot
   import dsa.da.util as util


except :
   import da.util_model as util_model
   import da.util_feature as util_feature
   import da.util_plot as util_plot
   import da.util as util


print(util_feature)
print("ok")
# Out:
# os.getcwd D:\_devs\Python01\gitdev\dsa\dsa
# <module 'da.util_feature' from 'D:\\_devs\\Python01\\gitdev\\dsa\\dsa\\da\\util_feature.py'>
# ok

# %% [markdown]
# # Data Loading, basic profiling

# %%
folder = os.getcwd() + "/"
print(folder)
# Out:
# D:\_devs\Python01\gitdev\dsa\dsa/

# %%
df = pd.read_csv(folder + '/data/address_matching_data.csv')
df.head(5)
# Out:
#             id  name_levenshtein_simple  ...  street_number_equality  is_match
# 0    1204#1207                 0.666667  ...                       s         1
# 1    1272#1279                 0.666667  ...                       s         1
# 2    6258#6259                 1.000000  ...                       s         1
# 3  16076#16077                 0.565476  ...                       n        -1
# 4    2666#2671                 0.666667  ...                       s         1
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#        name_levenshtein_simple  ...     is_match
# count             28235.000000  ...  28235.00000
# mean                  0.628171  ...      0.43524
# std                   0.304767  ...      0.90033
# min                   0.000000  ...     -1.00000
# 25%                   0.363387  ...     -1.00000
# 50%                   0.666667  ...      1.00000
# 75%                   1.000000  ...      1.00000
# max                   1.000000  ...      1.00000
#
# [8 rows x 5 columns]

# %%
df.columns, df.dtypes
# Out:
# (Index(['id', 'name_levenshtein_simple', 'name_trigram_simple',
#         'name_levenshtein_term', 'name_trigram_term', 'city_levenshtein_simple',
#         'city_trigram_simple', 'city_levenshtein_term', 'city_trigram_term',
#         'zip_levenshtein_simple', 'zip_trigram_simple', 'zip_levenshtein_term',
#         'zip_trigram_term', 'street_levenshtein_simple',
#         'street_trigram_simple', 'street_levenshtein_term',
#         'street_trigram_term', 'website_levenshtein_simple',
#         'website_trigram_simple', 'website_levenshtein_term',
#         'website_trigram_term', 'phone_levenshtein', 'phone_trigram',
#         'fax_levenshtein', 'fax_trigram', 'street_number_levenshtein',
#         'street_number_trigram', 'phone_equality', 'fax_equality',
#         'street_number_equality', 'is_match'],
#        dtype='object'), id                             object
#  name_levenshtein_simple       float64
#  name_trigram_simple           float64
#  name_levenshtein_term         float64
#  name_trigram_term             float64
#  city_levenshtein_simple        object
#  city_trigram_simple            object
#  city_levenshtein_term          object
#  city_trigram_term              object
#  zip_levenshtein_simple         object
#  zip_trigram_simple             object
#  zip_levenshtein_term           object
#  zip_trigram_term               object
#  street_levenshtein_simple      object
#  street_trigram_simple          object
#  street_levenshtein_term        object
#  street_trigram_term            object
#  website_levenshtein_simple     object
#  website_trigram_simple         object
#  website_levenshtein_term       object
#  website_trigram_term           object
#  phone_levenshtein              object
#  phone_trigram                  object
#  fax_levenshtein                object
#  fax_trigram                    object
#  street_number_levenshtein      object
#  street_number_trigram          object
#  phone_equality                 object
#  fax_equality                   object
#  street_number_equality         object
#  is_match                        int64
#  dtype: object)

# %%
# !pip3 install pandas_profiling
# Out:
# Collecting pandas_profiling
# Collecting jinja2>=2.8 (from pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/1d/e7/fd8b501e7a6dfe492a433deb7b9d833d39ca74916fa8bc63dd1a4947a671/Jinja2-2.10.1-py2.py3-none-any.whl
# Collecting htmlmin>=0.1.12 (from pandas_profiling)
# Collecting phik>=0.9.8 (from pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/45/ad/24a16fa4ba612fb96a3c4bb115a5b9741483f53b66d3d3afd987f20fa227/phik-0.9.8-py3-none-any.whl
# Collecting confuse>=1.0.0 (from pandas_profiling)
# Collecting missingno>=0.4.2 (from pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/2b/de/6e4dd6d720c49939544352155dc06a08c9f7e4271aa631a559dfbeaaf9d4/missingno-0.4.2-py3-none-any.whl
# Collecting pandas>=0.19 (from pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/73/9b/52e228545d14f14bb2a1622e225f38463c8726645165e1cb7dde95bfe6d4/pandas-0.25.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting matplotlib>=1.4 (from pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/57/4f/dd381ecf6c6ab9bcdaa8ea912e866dedc6e696756156d8ecc087e20817e2/matplotlib-3.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting astropy (from pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/7a/10/6e79f7b5ee8eb0a9210e1b3b950257ead3bdfbb1c8c29208bbead4fbecef/astropy-3.2.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting MarkupSafe>=0.23 (from jinja2>=2.8->pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting jupyter-client>=5.2.3 (from phik>=0.9.8->pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/07/61/0b923eefa2faa34d896665f136a0a6c26d721e910a661437cc615a0dc4ed/jupyter_client-5.3.3-py2.py3-none-any.whl
# Collecting pytest-pylint>=0.13.0 (from phik>=0.9.8->pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/64/dc/6f35f114844fb12e38d60c4f3d2441a55baff7043ad4e013777dff55746c/pytest_pylint-0.14.1-py3-none-any.whl
# Collecting numba>=0.38.1 (from phik>=0.9.8->pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/1d/18/75c4c9e75187d80813e0bf5231346e70f40e8f80de6a4554fc8a69e2ffc9/numba-0.45.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting nbconvert>=5.3.1 (from phik>=0.9.8->pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/f9/df/4505c0a7fea624cac461d0f41051f33456ae656753f65cee8c2f43121cb2/nbconvert-5.6.0-py2.py3-none-any.whl
# Collecting numpy>=1.15.4 (from phik>=0.9.8->pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/e5/e6/c3fdc53aed9fa19d6ff3abf97dfad768ae3afce1b7431f7500000816bda5/numpy-1.17.2-cp36-cp36m-manylinux1_x86_64.whl
# Collecting scipy>=1.1.0 (from phik>=0.9.8->pandas_profiling)
#   Using cached https://files.pythonhosted.org/packages/29/50/a552a5aff252ae915f522e44642bb49a7b7b31677f9580cfd11bcc869976/scipy-1.3.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting pytest>=4.0.2 (from phik>=0.9.8->pandas_profiling)
# ^C
# Operation cancelled by user

# %%
### Pandas Profiling for features
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
import pandas_profiling as pp
profile =  df.profile_report(title='Pandas Profiling Report')
profile.to_file(output_file="out/profile_na_handling.html")


colexclude = profile.get_rejected_variables(threshold=0.98)
colexclude
# Out:
# ['name_trigram_simple']

# %%
colexclude = profile.get_rejected_variables(threshold=0.98)
colexclude
# Out:
# ['name_trigram_simple']

# %% [markdown]
# # Column selection by type

# %%
colid = "id"
colnum = ['name_levenshtein_simple', 'name_trigram_simple',
        'name_levenshtein_term', 'name_trigram_term', 'city_levenshtein_simple',
        'city_trigram_simple', 'city_levenshtein_term', 'city_trigram_term',
        'zip_levenshtein_simple', 'zip_trigram_simple', 'zip_levenshtein_term',
        'zip_trigram_term', 'street_levenshtein_simple',
        'street_trigram_simple', 'street_levenshtein_term',
        'street_trigram_term', 'website_levenshtein_simple',
        'website_trigram_simple', 'website_levenshtein_term',
        'website_trigram_term', 'phone_levenshtein', 'phone_trigram',
        'fax_levenshtein', 'fax_trigram', 'street_number_levenshtein',
        'street_number_trigram']

colcat = [ 'phone_equality', 'fax_equality',
          'street_number_equality']
coltext = []

coldate = []

coly = "is_match"


colall = colnum + colcat + coltext

"""

dfnum, dfcat, dfnum_bin, 
dfnum_binhot,  dfcat_hot

colnum, colcat, coltext, 
colnum_bin, colnum_binhot,  

"""

print(colall )
# Out:
# ['name_levenshtein_simple', 'name_trigram_simple', 'name_levenshtein_term', 'name_trigram_term', 'city_levenshtein_simple', 'city_trigram_simple', 'city_levenshtein_term', 'city_trigram_term', 'zip_levenshtein_simple', 'zip_trigram_simple', 'zip_levenshtein_term', 'zip_trigram_term', 'street_levenshtein_simple', 'street_trigram_simple', 'street_levenshtein_term', 'street_trigram_term', 'website_levenshtein_simple', 'website_trigram_simple', 'website_levenshtein_term', 'website_trigram_term', 'phone_levenshtein', 'phone_trigram', 'fax_levenshtein', 'fax_trigram', 'street_number_levenshtein', 'street_number_trigram', 'phone_equality', 'fax_equality', 'street_number_equality']

# %%
df = df.set_index( colid )

# %% [markdown]
# # Data type normalization, Encoding process (numerics, category)

# %%
#Normalize to NA, NA Handling
df = df.replace("?", np.nan)

# %%
### colnum procesing 
for x in colnum :
    df[x] = df[x].astype("float32")

print( df.dtypes )
# Out:
# name_levenshtein_simple       float32
# name_trigram_simple           float32
# name_levenshtein_term         float32
# name_trigram_term             float32
# city_levenshtein_simple       float32
# city_trigram_simple           float32
# city_levenshtein_term         float32
# city_trigram_term             float32
# zip_levenshtein_simple        float32
# zip_trigram_simple            float32
# zip_levenshtein_term          float32
# zip_trigram_term              float32
# street_levenshtein_simple     float32
# street_trigram_simple         float32
# street_levenshtein_term       float32
# street_trigram_term           float32
# website_levenshtein_simple    float32
# website_trigram_simple        float32
# website_levenshtein_term      float32
# website_trigram_term          float32
# phone_levenshtein             float32
# phone_trigram                 float32
# fax_levenshtein               float32
# fax_trigram                   float32
# street_number_levenshtein     float32
# street_number_trigram         float32
# phone_equality                 object
# fax_equality                   object
# street_number_equality         object
# is_match                        int64
# dtype: object

# %%
##### Colcat processing 



colcat_map = util_feature.pd_colcat_mapping(df, colcat) 
                
#for col in colcat :
#    df[col] =  df[col].apply(lambda x : colcat_map["cat_map"][col].get(x)  )

print( df[colcat].dtypes , colcat_map)
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-15-d1cb2836f6d0>", line 5, in <module>
#     colcat_map = util_feature.pd_colcat_mapping(df, colcat)
#
# NameError: name 'util_feature' is not defined

# %% [markdown]
# # Data Distribution after encoding/ data type normalization

# %%
#### ColTarget Distribution
coly_stat = pd_stat_distribution(df[  [  "id", coly ]] ,  subsample_ratio= 1.0)
coly_stat
# Out:
# Univariate distribution
# id must be str, not float
#         col        n  n_na  n_notna  n_na_pct  nunique  nunique_pct  xmin  \
# 0  is_match  28235.0   0.0    28235       0.0        2     0.000071    -1
#
#    xmin_freq  xmin_pct  xmax  xmax_freq  xmax_pct  xmed  xmed_freq  xmed_pct
# 0       7973   0.28238     1      20262   0.71762   1.0      20262   0.71762

# %%
#### Col numerics distribution
colnum_stat = pd_stat_distribution(df[colnum],  subsample_ratio= 0.6)
colnum_stat
# Out:
# Univariate distribution
#                            col        n     n_na  n_notna  n_na_pct  nunique  \
# 0      name_levenshtein_simple  16941.0      0.0    16941  0.000000     2577
# 1          name_trigram_simple  16941.0      0.0    16941  0.000000     1389
# 2        name_levenshtein_term  16941.0      0.0    16941  0.000000      652
# 3            name_trigram_term  16941.0      0.0    16941  0.000000      791
# 4      city_levenshtein_simple  16941.0  11021.0     5920  0.650552      174
# 5          city_trigram_simple  16941.0  11021.0     5920  0.650552       91
# 6        city_levenshtein_term  16941.0  11021.0     5920  0.650552       99
# 7            city_trigram_term  16941.0  11021.0     5920  0.650552      100
# 8       zip_levenshtein_simple  16941.0  12328.0     4613  0.727702       17
# 9           zip_trigram_simple  16941.0  12328.0     4613  0.727702       20
# 10        zip_levenshtein_term  16941.0  12328.0     4613  0.727702       22
# 11            zip_trigram_term  16941.0  12328.0     4613  0.727702       25
# 12   street_levenshtein_simple  16941.0  12027.0     4914  0.709934     1227
# 13       street_trigram_simple  16941.0  12027.0     4914  0.709934      691
# 14     street_levenshtein_term  16941.0  12027.0     4914  0.709934      430
# 15         street_trigram_term  16941.0  12027.0     4914  0.709934      532
# 16  website_levenshtein_simple  16941.0  15852.0     1089  0.935718      234
# 17      website_trigram_simple  16941.0  15852.0     1089  0.935718      161
# 18    website_levenshtein_term  16941.0  15852.0     1089  0.935718      182
# 19        website_trigram_term  16941.0  15852.0     1089  0.935718      225
# 20           phone_levenshtein  16941.0   9799.0     7142  0.578419       28
# 21               phone_trigram  16941.0   9799.0     7142  0.578419       55
# 22             fax_levenshtein  16941.0  16508.0      433  0.974441       18
# 23                 fax_trigram  16941.0  16508.0      433  0.974441       25
# 24   street_number_levenshtein  16941.0   5905.0    11036  0.348563       15
# 25       street_number_trigram  16941.0   5905.0    11036  0.348563       24
#
#     nunique_pct      xmin  xmin_freq  xmin_pct  xmax  xmax_freq  xmax_pct  \
# 0      0.152116  0.000000        126  0.007438   1.0       4227  0.249513
# 1      0.081990  0.000000       2029  0.119769   1.0       4227  0.249513
# 2      0.038487  0.000000        151  0.008913   1.0       3891  0.229679
# 3      0.046691  0.000000       2027  0.119651   1.0       4243  0.250457
# 4      0.010271  0.000000         81  0.004781   1.0       4566  0.269524
# 5      0.005372  0.000000        390  0.023021   1.0       4566  0.269524
# 6      0.005844  0.000000         81  0.004781   1.0       4674  0.275899
# 7      0.005903  0.000000        390  0.023021   1.0       4678  0.276135
# 8      0.001003  0.000000        191  0.011274   1.0       3549  0.209492
# 9      0.001181  0.000000        344  0.020306   1.0       3552  0.209669
# 10     0.001299  0.000000        191  0.011274   1.0       3549  0.209492
# 11     0.001476  0.000000        344  0.020306   1.0       3552  0.209669
# 12     0.072428  0.000000          9  0.000531   1.0       1695  0.100053
# 13     0.040789  0.000000        350  0.020660   1.0       1695  0.100053
# 14     0.025382  0.000000          6  0.000354   1.0       1767  0.104303
# 15     0.031403  0.000000        346  0.020424   1.0       1783  0.105248
# 16     0.013813  0.175000          2  0.000118   1.0        545  0.032170
# 17     0.009504  0.028219          2  0.000118   1.0        545  0.032170
# 18     0.010743  0.061856          2  0.000118   1.0        545  0.032170
# 19     0.013281  0.025316          6  0.000354   1.0        547  0.032289
# 20     0.001653  0.100000         57  0.003365   1.0       4715  0.278319
# 21     0.003247  0.000000          2  0.000118   1.0       4715  0.278319
# 22     0.001063  0.100000          8  0.000472   1.0        236  0.013931
# 23     0.001476  0.047619         28  0.001653   1.0        236  0.013931
# 24     0.000885  0.000000        162  0.009563   1.0       8413  0.496606
# 25     0.001417  0.000000        185  0.010920   1.0       8413  0.496606
#
#         xmed  xmed_freq  xmed_pct
# 0   0.666667       3404  0.200933
# 1   0.666667       2914  0.172009
# 2   0.473684       3038  0.179328
# 3   0.478261       2737  0.161561
# 4   1.000000       4579  0.270291
# 5   1.000000       4566  0.269524
# 6   1.000000       4675  0.275958
# 7   1.000000       4678  0.276135
# 8   1.000000       3549  0.209492
# 9   1.000000       3552  0.209669
# 10  1.000000       3549  0.209492
# 11  1.000000       3552  0.209669
# 12  0.800000        923  0.054483
# 13  0.750000        728  0.042973
# 14  0.782609        645  0.038073
# 15  0.722222        550  0.032466
# 16  1.000000        562  0.033174
# 17  1.000000        558  0.032938
# 18  1.000000        577  0.034059
# 19  1.000000        548  0.032348
# 20  1.000000       4876  0.287822
# 21  1.000000       4715  0.278319
# 22  1.000000        243  0.014344
# 23  1.000000        236  0.013931
# 24  1.000000       8413  0.496606
# 25  1.000000       8413  0.496606

# %%
#### Col stats distribution
colcat_stat = util_feature.pd_stat_distribution(df[colcat], subsample_ratio= 0.3)
colcat_stat
# Out:
# Univariate distribution
# phone_equality must be str, not float
# fax_equality must be str, not float
# street_number_equality must be str, not float
# Empty DataFrame
# Columns: [col, n, n_na, n_notna, n_na_pct, nunique, nunique_pct, xmin, xmin_freq, xmin_pct, xmax, xmax_freq, xmax_pct, xmed, xmed_freq, xmed_pct]
# Index: []

# %% [markdown]
# # Feature processing (strategy 1)

# %%
### BAcKUP data before Pre-processing
dfref = copy.deepcopy( df )
print(dfref.shape)
# Out:
# (28235, 31)

# %%
"""
Many strategies are possible :
   1) Feature selection before the model
   2) Feature selection using model accuracy.
   
Unless of those cases :
   variable with correl > 99% (ie > imablance class %).
   variable with variance of 0 (as 0).
   Its better to keep all variables at 1st.
   Only Linear model (ie Regression, Logitsic) : 




"""

# %% [markdown]
# ## Colnum

# %%
## Map numerics to Category bin
dfnum, colnum_binmap = util_feature.pd_colnum_tocat(df, colname=colnum, colexclude=None, colbinmap=None,
                                  bins=5, suffix="_bin",    method="uniform",
                                  return_val="dataframe,param")


print(colnum_binmap)
# Out:
# name_levenshtein_simple
#                             name_levenshtein_simple
#                                                 max  min      mean   size
# name_levenshtein_simple_bin
# 0                                          0.199916  0.0  0.133234   3244
# 1                                          0.399802  0.2  0.284679   4352
# 2                                          0.599206  0.4  0.495519   4713
# 3                                          0.797778  0.6  0.679888   4992
# 4                                          1.000000  0.8  0.945298  10934
# name_trigram_simple
#                         name_trigram_simple
#                                         max  min      mean   size
# name_trigram_simple_bin
# 0                                  0.199356  0.0  0.034203   6913
# 1                                  0.398810  0.2  0.303970   2304
# 2                                  0.598639  0.4  0.493030   4347
# 3                                  0.793269  0.6  0.681848   4046
# 4                                  1.000000  0.8  0.947331  10625
# name_levenshtein_term
#                           name_levenshtein_term
#                                             max  min      mean  size
# name_levenshtein_term_bin
# 0                                      0.196429  0.0  0.128121  4796
# 1                                      0.397059  0.2  0.283608  7258
# 2                                      0.595745  0.4  0.494029  4867
# 3                                      0.793103  0.6  0.688375  3306
# 4                                      1.000000  0.8  0.975184  8008
# name_trigram_term
#                       name_trigram_term
#                                     max  min      mean  size
# name_trigram_term_bin
# 0                              0.196970  0.0  0.044257  7820
# 1                              0.395833  0.2  0.305079  4141
# 2                              0.596774  0.4  0.490261  4378
# 3                              0.795455  0.6  0.688602  3371
# 4                              1.000000  0.8  0.974722  8525
# city_levenshtein_simple
#                             city_levenshtein_simple
#                                                 max  min      mean   size
# city_levenshtein_simple_bin
# -1                                              NaN  NaN       NaN  18290
#  0                                         0.197917  0.0  0.095143    540
#  1                                         0.397959  0.2  0.274496    287
#  2                                         0.583333  0.4  0.543002    311
#  3                                         0.792857  0.6  0.665268    873
#  4                                         1.000000  0.8  0.995194   7934
# city_trigram_simple
#                         city_trigram_simple
#                                         max       min      mean   size
# city_trigram_simple_bin
# -1                                      NaN       NaN       NaN  18290
#  0                                 0.190476  0.000000  0.018133    857
#  1                                 0.375000  0.200000  0.336874    414
#  2                                 0.583333  0.400000  0.485682    141
#  3                                 0.791667  0.602778  0.670119    794
#  4                                 1.000000  0.800000  0.998901   7739
# city_levenshtein_term
#                           city_levenshtein_term
#                                             max  min      mean   size
# city_levenshtein_term_bin
# -1                                          NaN  NaN       NaN  18290
#  0                                     0.192308  0.0  0.097827    645
#  1                                     0.384615  0.2  0.266688    249
#  2                                     0.583333  0.4  0.499026    975
#  3                                     0.785714  0.6  0.669885    172
#  4                                     1.000000  0.8  0.999129   7904
# city_trigram_term
#                       city_trigram_term
#                                     max  min      mean   size
# city_trigram_term_bin
# -1                                  NaN  NaN       NaN  18290
#  0                             0.193548  0.0  0.017975    859
#  1                             0.391304  0.2  0.351800    295
#  2                             0.588235  0.4  0.514457    743
#  3                             0.782609  0.6  0.673442    172
#  4                             1.000000  0.8  0.999780   7876
# zip_levenshtein_simple
#                            zip_levenshtein_simple
#                                               max  min      mean   size
# zip_levenshtein_simple_bin
# -1                                            NaN  NaN       NaN  20539
#  0                                       0.166667  0.0  0.003788    308
#  1                                       0.333333  0.2  0.222763    261
#  2                                       0.533333  0.4  0.456685    104
#  3                                       0.750000  0.6  0.647233    271
#  4                                       1.000000  0.8  0.977009   6752
# zip_trigram_simple
#                        zip_trigram_simple
#                                       max       min      mean   size
# zip_trigram_simple_bin
# -1                                    NaN       NaN       NaN  20539
#  0                               0.181818  0.000000  0.013905    617
#  1                               0.375000  0.200000  0.316570    673
#  2                               0.571429  0.428571  0.528895    309
#  3                               0.666667  0.600000  0.664021    126
#  4                               1.000000  1.000000  1.000000   5971
# zip_levenshtein_term
#                          zip_levenshtein_term
#                                           max  min      mean   size
# zip_levenshtein_term_bin
# -1                                        NaN  NaN       NaN  20539
#  0                                   0.142857  0.0  0.003711    308
#  1                                   0.375000  0.2  0.236913    295
#  2                                   0.571429  0.4  0.453307    151
#  3                                   0.750000  0.6  0.653425    187
#  4                                   1.000000  0.8  0.977079   6755
# zip_trigram_term
#                      zip_trigram_term
#                                   max  min      mean   size
# zip_trigram_term_bin
# -1                                NaN  NaN       NaN  20539
#  0                           0.181818  0.0  0.013858    617
#  1                           0.375000  0.2  0.316307    678
#  2                           0.571429  0.4  0.504769    396
#  3                           0.666667  0.6  0.604167     34
#  4                           1.000000  1.0  1.000000   5971
# street_levenshtein_simple
#                               street_levenshtein_simple
#                                                     max  min      mean   size
# street_levenshtein_simple_bin
# -1                                                  NaN  NaN       NaN  19997
#  0                                             0.198810  0.0  0.139081    615
#  1                                             0.399471  0.2  0.298834   1548
#  2                                             0.596429  0.4  0.488772    874
#  3                                             0.798611  0.6  0.705490   1015
#  4                                             1.000000  0.8  0.958354   4186
# street_trigram_simple
#                           street_trigram_simple
#                                             max  min      mean   size
# street_trigram_simple_bin
# -1                                          NaN  NaN       NaN  19997
#  0                                     0.198485  0.0  0.038069   1669
#  1                                     0.399669  0.2  0.281841   1020
#  2                                     0.596875  0.4  0.499309    575
#  3                                     0.793651  0.6  0.706532   1026
#  4                                     1.000000  0.8  0.958941   3948
# street_levenshtein_term
#                             street_levenshtein_term
#                                                 max  min      mean   size
# street_levenshtein_term_bin
# -1                                              NaN  NaN       NaN  19997
#  0                                         0.196721  0.0  0.142500    713
#  1                                         0.394737  0.2  0.285521   1847
#  2                                         0.595238  0.4  0.485934    882
#  3                                         0.794118  0.6  0.703717    666
#  4                                         1.000000  0.8  0.965269   4130
# street_trigram_term
#                         street_trigram_term
#                                         max  min      mean   size
# street_trigram_term_bin
# -1                                      NaN  NaN       NaN  19997
#  0                                 0.195652  0.0  0.068234   2532
#  1                                 0.396825  0.2  0.287067    522
#  2                                 0.596491  0.4  0.512796    569
#  3                                 0.796610  0.6  0.712352    854
#  4                                 1.000000  0.8  0.970748   3761
# website_levenshtein_simple
#                                website_levenshtein_simple  ...
#                                                       max  ...   size
# website_levenshtein_simple_bin                             ...
# -1                                               1.000000  ...  27322
#  0                                               0.335924  ...     43
#  1                                               0.504762  ...    187
#  2                                               0.668750  ...    281
#  3                                               0.833333  ...    251
#  4                                               0.979167  ...    151
#
# [6 rows x 4 columns]
# website_trigram_simple
#                            website_trigram_simple
#                                               max       min      mean   size
# website_trigram_simple_bin
# -1                                            NaN       NaN       NaN  26416
#  0                                       0.212903  0.028219  0.127279     45
#  1                                       0.414286  0.223214  0.346492    163
#  2                                       0.606061  0.420000  0.486172    292
#  3                                       0.800000  0.613889  0.722279    254
#  4                                       1.000000  0.810458  0.978935   1065
# website_levenshtein_term
#                              website_levenshtein_term  ...
#                                                   max  ...   size
# website_levenshtein_term_bin                           ...
# -1                                                NaN  ...  26416
#  0                                           0.247191  ...     57
#  1                                           0.434783  ...    352
#  2                                           0.621622  ...    217
#  3                                           0.809524  ...    159
#  4                                           1.000000  ...   1034
#
# [6 rows x 4 columns]
# website_trigram_term
#                          website_trigram_term
#                                           max       min      mean   size
# website_trigram_term_bin
# -1                                        NaN       NaN       NaN  26416
#  0                                   0.219512  0.025316  0.166508    236
#  1                                   0.413793  0.220339  0.302246    283
#  2                                   0.609756  0.424242  0.518842    154
#  3                                   0.800000  0.617647  0.718212    137
#  4                                   1.000000  0.806452  0.984178   1009
# phone_levenshtein
#                       phone_levenshtein
#                                     max       min      mean   size
# phone_levenshtein_bin
# -1                             1.000000  1.000000  1.000000  24234
#  0                             0.272727  0.100000  0.205098    609
#  1                             0.454545  0.300000  0.398655   1033
#  2                             0.636364  0.500000  0.571395   1240
#  3                             0.818182  0.666667  0.766481    776
#  4                             0.916667  0.833333  0.902960    343
# phone_trigram
#                   phone_trigram
#                             max  min      mean   size
# phone_trigram_bin
# -1                          NaN  NaN       NaN  16371
#  0                     0.187500  0.0  0.091661   1042
#  1                     0.375000  0.2  0.274957   1731
#  2                     0.571429  0.4  0.459597    618
#  3                     0.733333  0.6  0.635614    610
#  4                     1.000000  1.0  1.000000   7863
# fax_levenshtein
#                     fax_levenshtein
#                                 max  min      mean   size
# fax_levenshtein_bin
# -1                         1.000000  1.0  1.000000  27891
#  0                         0.272727  0.1  0.175401     34
#  1                         0.454545  0.3  0.384269    115
#  2                         0.636364  0.5  0.553706    130
#  3                         0.818182  0.7  0.725046     49
#  4                         0.909091  0.9  0.907386     16
# fax_trigram
#                 fax_trigram
#                         max       min      mean   size
# fax_trigram_bin
# -1                      NaN       NaN       NaN  27505
#  0                 0.235294  0.047619  0.150437    182
#  1                 0.411765  0.263158  0.325706    120
#  2                 0.600000  0.428571  0.506250     32
#  3                 0.714286  0.692308  0.709890     10
#  4                 1.000000  1.000000  1.000000    386
# street_number_levenshtein
#                               street_number_levenshtein
#                                                     max  min      mean   size
# street_number_levenshtein_bin
# -1                                                  NaN  NaN       NaN   9852
#  0                                             0.000000  0.0  0.000000    285
#  1                                             0.333333  0.2  0.293634    144
#  2                                             0.571429  0.4  0.482608   2382
#  3                                             0.750000  0.6  0.702021   1417
#  4                                             1.000000  0.8  0.998723  14155
# street_number_trigram
#                           street_number_trigram
#                                             max  min      mean   size
# street_number_trigram_bin
# -1                                          NaN  NaN       NaN   9852
#  0                                     0.181818  0.0  0.073064    551
#  1                                     0.375000  0.2  0.270634   3084
#  2                                     0.571429  0.4  0.447116    684
#  4                                     1.000000  1.0  1.000000  14064
# OrderedDict([('name_levenshtein_simple', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('name_trigram_simple', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('name_levenshtein_term', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('name_trigram_term', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('city_levenshtein_simple', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('city_trigram_simple', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('city_levenshtein_term', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('city_trigram_term', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('zip_levenshtein_simple', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('zip_trigram_simple', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('zip_levenshtein_term', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('zip_trigram_term', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('street_levenshtein_simple', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('street_trigram_simple', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('street_levenshtein_term', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('street_trigram_term', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('website_levenshtein_simple', [0.17489999701976777, 0.33999999463558195, 0.5049999922513961, 0.6699999898672104, 0.8349999874830246, 0.9999999850988388]), ('website_trigram_simple', [0.028118699619174004, 0.2225749623030424, 0.4169312249869108, 0.6112874876707792, 0.8056437503546476, 1.000000013038516]), ('website_levenshtein_term', [0.061755699867010114, 0.2494845651090145, 0.4371134303510189, 0.6247422955930233, 0.8123711608350277, 1.000000026077032]), ('website_trigram_term', [0.025216499173641205, 0.22025320380926133, 0.41518990844488146, 0.6101266130805016, 0.8050633177161217, 1.0000000223517418]), ('phone_levenshtein', [0.09990000149011612, 0.2799999967217445, 0.45999999195337293, 0.6399999871850013, 0.8199999824166297, 0.9999999776482582]), ('phone_trigram', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('fax_levenshtein', [0.09990000149011612, 0.2799999967217445, 0.45999999195337293, 0.6399999871850013, 0.8199999824166297, 0.9999999776482582]), ('fax_trigram', [0.0475190485060215, 0.23809523954987527, 0.42857143059372904, 0.6190476216375829, 0.8095238126814366, 1.0000000037252903]), ('street_number_levenshtein', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0]), ('street_number_trigram', [-0.0001, 0.2, 0.4, 0.6000000000000001, 0.8, 1.0])])

# %%
colnum_bin =  [  x + "_bin" for x in  list( colnum_binmap.keys() )   ]
print( colnum_bin )
# Out:
# ['name_levenshtein_simple_bin', 'name_trigram_simple_bin', 'name_levenshtein_term_bin', 'name_trigram_term_bin', 'city_levenshtein_simple_bin', 'city_trigram_simple_bin', 'city_levenshtein_term_bin', 'city_trigram_term_bin', 'zip_levenshtein_simple_bin', 'zip_trigram_simple_bin', 'zip_levenshtein_term_bin', 'zip_trigram_term_bin', 'street_levenshtein_simple_bin', 'street_trigram_simple_bin', 'street_levenshtein_term_bin', 'street_trigram_term_bin', 'website_levenshtein_simple_bin', 'website_trigram_simple_bin', 'website_levenshtein_term_bin', 'website_trigram_term_bin', 'phone_levenshtein_bin', 'phone_trigram_bin', 'fax_levenshtein_bin', 'fax_trigram_bin', 'street_number_levenshtein_bin', 'street_number_trigram_bin']

# %%
dfnum.columns
# Out:
# Index(['name_levenshtein_simple_bin', 'name_trigram_simple_bin',
#        'name_levenshtein_term_bin', 'name_trigram_term_bin',
#        'city_levenshtein_simple_bin', 'city_trigram_simple_bin',
#        'city_levenshtein_term_bin', 'city_trigram_term_bin',
#        'zip_levenshtein_simple_bin', 'zip_trigram_simple_bin',
#        'zip_levenshtein_term_bin', 'zip_trigram_term_bin',
#        'street_levenshtein_simple_bin', 'street_trigram_simple_bin',
#        'street_levenshtein_term_bin', 'street_trigram_term_bin',
#        'website_levenshtein_simple_bin', 'website_trigram_simple_bin',
#        'website_levenshtein_term_bin', 'website_trigram_term_bin',
#        'phone_levenshtein_bin', 'phone_trigram_bin', 'fax_levenshtein_bin',
#        'fax_trigram_bin', 'street_number_levenshtein_bin',
#        'street_number_trigram_bin'],
#       dtype='object')

# %%
### numerics bin to One Hot
dfnum_hot, colnum_onehot = util_feature.pd_col_to_onehot(dfnum[colnum_bin], colname=colnum_bin,
                             colonehot=None, return_val="dataframe,param")
dfnum_hot[ colnum_onehot   ] .head(10)
# Out:
# name_levenshtein_simple_bin 5 (28235, 26)
# name_trigram_simple_bin 5 (28235, 30)
# name_levenshtein_term_bin 5 (28235, 34)
# name_trigram_term_bin 5 (28235, 38)
# city_levenshtein_simple_bin 6 (28235, 42)
# city_trigram_simple_bin 6 (28235, 47)
# city_levenshtein_term_bin 6 (28235, 52)
# city_trigram_term_bin 6 (28235, 57)
# zip_levenshtein_simple_bin 6 (28235, 62)
# zip_trigram_simple_bin 6 (28235, 67)
# zip_levenshtein_term_bin 6 (28235, 72)
# zip_trigram_term_bin 6 (28235, 77)
# street_levenshtein_simple_bin 6 (28235, 82)
# street_trigram_simple_bin 6 (28235, 87)
# street_levenshtein_term_bin 6 (28235, 92)
# street_trigram_term_bin 6 (28235, 97)
# website_levenshtein_simple_bin 6 (28235, 102)
# website_trigram_simple_bin 6 (28235, 107)
# website_levenshtein_term_bin 6 (28235, 112)
# website_trigram_term_bin 6 (28235, 117)
# phone_levenshtein_bin 6 (28235, 122)
# phone_trigram_bin 6 (28235, 127)
# fax_levenshtein_bin 6 (28235, 132)
# fax_trigram_bin 6 (28235, 137)
# street_number_levenshtein_bin 6 (28235, 142)
# street_number_trigram_bin 5 (28235, 147)
#              name_levenshtein_simple_bin_0  ...  street_number_trigram_bin_4
# id                                          ...
# 1204#1207                                0  ...                            1
# 1272#1279                                0  ...                            1
# 6258#6259                                0  ...                            1
# 16076#16077                              0  ...                            0
# 2666#2671                                0  ...                            1
# 4402#4403                                0  ...                            1
# 4025#4028                                1  ...                            0
# 4126#4138                                0  ...                            0
# 4559#4560                                1  ...                            0
# 15610#15611                              0  ...                            0
#
# [10 rows x 151 columns]

# %%
0
# Out:
# 0

# %%
## To pipeline
#  Save each feature processing into "Reproductible pipeline".
#  For Scalability, for repreoduction process
#  Functionnal appraoch --> Can be converted to Spark
#  For scalbility, and paralell


pipe_preprocess_colnum =[ 
           (util_feature.pd_col_to_num,   {"default": np.nan,} , "Conver string to NA")
           
          ,(util_feature.pd_colnum_tocat, { "colname":None, "colbinmap": colnum_binmap,  'bins': 5, 
                               "method": "uniform", "suffix":"_bin", "return_val": "dataframe"}, 
                               "Convert Numerics to Category " )
           
          ,(util_feature.pd_col_to_onehot, { "colname": None,  "colonehot": colnum_onehot,  
                                "return_val": "dataframe"  } , 
                                "Convert category to onehot" )
]

# %%
###Check pipeline
util_feature.pd_pipeline_apply( df[colnum].iloc[:10000,:], pipe_preprocess_colnum)
# Out:
# ############## Pipeline  0 Start (10000, 26) pd_col_to_num
# ############## Pipeline   0 Finished (10000, 26)
# ############## Pipeline  1 Start (10000, 26) pd_colnum_tocat
# name_levenshtein_simple
#                             name_levenshtein_simple
#                                                 max  min      mean  size
# name_levenshtein_simple_bin
# 0                                          0.199916  0.0  0.133397  1173
# 1                                          0.399802  0.2  0.284577  1542
# 2                                          0.598214  0.4  0.497450  1624
# 3                                          0.797778  0.6  0.679548  1800
# 4                                          1.000000  0.8  0.945058  3861
# name_trigram_simple
#                         name_trigram_simple
#                                         max  min      mean  size
# name_trigram_simple_bin
# 0                                  0.199356  0.0  0.032877  2461
# 1                                  0.398810  0.2  0.305268   806
# 2                                  0.595238  0.4  0.493260  1519
# 3                                  0.793269  0.6  0.681216  1464
# 4                                  1.000000  0.8  0.946988  3750
# name_levenshtein_term
#                           name_levenshtein_term
#                                             max  min      mean  size
# name_levenshtein_term_bin
# 0                                      0.196429  0.0  0.127442  1739
# 1                                      0.395349  0.2  0.284173  2530
# 2                                      0.595745  0.4  0.496032  1740
# 3                                      0.793103  0.6  0.688033  1160
# 4                                      1.000000  0.8  0.974470  2831
# name_trigram_term
#                       name_trigram_term
#                                     max  min      mean  size
# name_trigram_term_bin
# 0                              0.196429  0.0  0.042941  2769
# 1                              0.395833  0.2  0.305185  1450
# 2                              0.596154  0.4  0.491540  1565
# 3                              0.793103  0.6  0.688467  1199
# 4                              1.000000  0.8  0.973549  3017
# city_levenshtein_simple
#                             city_levenshtein_simple
#                                                 max  min      mean  size
# city_levenshtein_simple_bin
# -1                                              NaN  NaN       NaN  6500
#  0                                         0.197917  0.0  0.095789   189
#  1                                         0.397959  0.2  0.270749    92
#  2                                         0.571429  0.4  0.543726   108
#  3                                         0.792857  0.6  0.666680   333
#  4                                         1.000000  0.8  0.994885  2778
# city_trigram_simple
#                         city_trigram_simple
#                                         max       min      mean  size
# city_trigram_simple_bin
# -1                                      NaN       NaN       NaN  6500
#  0                                 0.181319  0.000000  0.017427   293
#  1                                 0.363636  0.217866  0.336913   148
#  2                                 0.562500  0.400000  0.469695    38
#  3                                 0.781250  0.642857  0.669812   312
#  4                                 1.000000  0.800000  0.998739  2709
# city_levenshtein_term
#                           city_levenshtein_term
#                                             max  min      mean  size
# city_levenshtein_term_bin
# -1                                          NaN  NaN       NaN  6500
#  0                                     0.192308  0.0  0.097087   221
#  1                                     0.384615  0.2  0.262421    77
#  2                                     0.571429  0.4  0.498763   378
#  3                                     0.777778  0.6  0.664999    55
#  4                                     1.000000  0.8  0.998976  2769
# city_trigram_term
#                       city_trigram_term
#                                     max       min      mean  size
# city_trigram_term_bin
# -1                                  NaN       NaN       NaN  6500
#  0                             0.181818  0.000000  0.017318   295
#  1                             0.391304  0.212121  0.356431    96
#  2                             0.560000  0.400000  0.516044   283
#  3                             0.750000  0.600000  0.665713    66
#  4                             1.000000  0.800000  0.999526  2760
# zip_levenshtein_simple
#                            zip_levenshtein_simple
#                                               max  min      mean  size
# zip_levenshtein_simple_bin
# -1                                            NaN  NaN       NaN  7287
#  0                                       0.166667  0.0  0.003333   100
#  1                                       0.285714  0.2  0.222557    90
#  2                                       0.533333  0.4  0.449104    31
#  3                                       0.750000  0.6  0.650375    89
#  4                                       1.000000  0.8  0.976113  2403
# zip_trigram_simple
#                        zip_trigram_simple
#                                       max       min      mean  size
# zip_trigram_simple_bin
# -1                                    NaN       NaN       NaN  7287
#  0                               0.142857  0.000000  0.009627   201
#  1                               0.375000  0.200000  0.318207   245
#  2                               0.571429  0.428571  0.532766   109
#  3                               0.666667  0.666667  0.666667    44
#  4                               1.000000  1.000000  1.000000  2114
# zip_levenshtein_term
#                          zip_levenshtein_term
#                                           max  min      mean  size
# zip_levenshtein_term_bin
# -1                                        NaN  NaN       NaN  7287
#  0                                   0.142857  0.0  0.004286   100
#  1                                   0.375000  0.2  0.235738   100
#  2                                   0.571429  0.4  0.446928    52
#  3                                   0.750000  0.6  0.656057    57
#  4                                   1.000000  0.8  0.976197  2404
# zip_trigram_term
#                      zip_trigram_term
#                                   max  min      mean  size
# zip_trigram_term_bin
# -1                                NaN  NaN       NaN  7287
#  0                           0.142857  0.0  0.009516   201
#  1                           0.375000  0.2  0.317794   247
#  2                           0.571429  0.4  0.507962   141
#  3                           0.600000  0.6  0.600000    10
#  4                           1.000000  1.0  1.000000  2114
# street_levenshtein_simple
#                               street_levenshtein_simple
#                                                     max  min      mean  size
# street_levenshtein_simple_bin
# -1                                                  NaN  NaN       NaN  7097
#  0                                             0.198413  0.0  0.137165   213
#  1                                             0.398810  0.2  0.299179   547
#  2                                             0.596296  0.4  0.491523   291
#  3                                             0.798611  0.6  0.706195   347
#  4                                             1.000000  0.8  0.960315  1505
# street_trigram_simple
#                           street_trigram_simple
#                                             max  min      mean  size
# street_trigram_simple_bin
# -1                                          NaN  NaN       NaN  7097
#  0                                     0.193182  0.0  0.036992   581
#  1                                     0.398333  0.2  0.281695   351
#  2                                     0.595238  0.4  0.507900   199
#  3                                     0.793651  0.6  0.702810   336
#  4                                     1.000000  0.8  0.960018  1436
# street_levenshtein_term
#                             street_levenshtein_term
#                                                 max  min      mean  size
# street_levenshtein_term_bin
# -1                                              NaN  NaN       NaN  7097
#  0                                         0.195652  0.0  0.141730   245
#  1                                         0.392857  0.2  0.284425   652
#  2                                         0.593750  0.4  0.486801   301
#  3                                         0.793103  0.6  0.702867   231
#  4                                         1.000000  0.8  0.967451  1474
# street_trigram_term
#                         street_trigram_term
#                                         max  min      mean  size
# street_trigram_term_bin
# -1                                      NaN  NaN       NaN  7097
#  0                                 0.195652  0.0  0.067243   872
#  1                                 0.396825  0.2  0.286244   187
#  2                                 0.594595  0.4  0.517053   196
#  3                                 0.793103  0.6  0.706331   284
#  4                                 1.000000  0.8  0.972488  1364
# website_levenshtein_simple
#                                website_levenshtein_simple  ...
#                                                       max  ...  size
# website_levenshtein_simple_bin                             ...
# -1                                               1.000000  ...  9668
#  0                                               0.333333  ...    18
#  1                                               0.502083  ...    71
#  2                                               0.668750  ...    99
#  3                                               0.833333  ...    99
#  4                                               0.977273  ...    45
#
# [6 rows x 4 columns]
# website_trigram_simple
#                            website_trigram_simple
#                                               max       min      mean  size
# website_trigram_simple_bin
# -1                                            NaN       NaN       NaN  9322
#  0                                       0.207407  0.028219  0.114844    21
#  1                                       0.410256  0.223214  0.357300    59
#  2                                       0.600000  0.427140  0.483667   106
#  3                                       0.800000  0.615385  0.727764    99
#  4                                       1.000000  0.810458  0.984014   393
# website_levenshtein_term
#                              website_levenshtein_term
#                                                   max       min      mean  size
# website_levenshtein_term_bin
# -1                                                NaN       NaN       NaN  9322
#  0                                           0.246753  0.061856  0.199124    27
#  1                                           0.428571  0.250000  0.334420   125
#  2                                           0.621622  0.440000  0.538313    81
#  3                                           0.809524  0.625000  0.707433    55
#  4                                           1.000000  0.827586  0.986699   390
# website_trigram_term
#                          website_trigram_term
#                                           max       min      mean  size
# website_trigram_term_bin
# -1                                        NaN       NaN       NaN  9322
#  0                                   0.219178  0.025316  0.162805    91
#  1                                   0.413793  0.220339  0.305664   105
#  2                                   0.605263  0.424242  0.505342    51
#  3                                   0.787879  0.621622  0.725173    54
#  4                                   1.000000  0.806452  0.987137   377
# phone_levenshtein
#                       phone_levenshtein
#                                     max       min      mean  size
# phone_levenshtein_bin
# -1                             1.000000  1.000000  1.000000  8615
#  0                             0.272727  0.100000  0.204214   206
#  1                             0.454545  0.300000  0.398802   373
#  2                             0.636364  0.500000  0.571060   419
#  3                             0.818182  0.666667  0.760348   276
#  4                             0.916667  0.833333  0.901556   111
# phone_trigram
#                   phone_trigram
#                             max  min      mean  size
# phone_trigram_bin
# -1                          NaN  NaN       NaN  5771
#  0                     0.181818  0.0  0.090134   364
#  1                     0.375000  0.2  0.272972   588
#  2                     0.571429  0.4  0.460406   242
#  3                     0.733333  0.6  0.636180   191
#  4                     1.000000  1.0  1.000000  2844
# fax_levenshtein
#                     fax_levenshtein
#                                 max  min      mean  size
# fax_levenshtein_bin
# -1                         1.000000  1.0  1.000000  9878
#  0                         0.272727  0.1  0.187013    14
#  1                         0.454545  0.3  0.371770    38
#  2                         0.636364  0.5  0.544040    45
#  3                         0.818182  0.7  0.726768    18
#  4                         0.909091  0.9  0.906494     7
# fax_trigram
#                 fax_trigram
#                         max       min      mean  size
# fax_trigram_bin
# -1                      NaN       NaN       NaN  9748
#  0                 0.235294  0.047619  0.146204    66
#  1                 0.411765  0.263158  0.329494    41
#  2                 0.600000  0.428571  0.510000    10
#  3                 0.714286  0.692308  0.709890     5
#  4                 1.000000  1.000000  1.000000   130
# street_number_levenshtein
#                               street_number_levenshtein
#                                                     max   min      mean  size
# street_number_levenshtein_bin
# -1                                                  NaN   NaN       NaN  3487
#  0                                             0.000000  0.00  0.000000   100
#  1                                             0.333333  0.25  0.296721    53
#  2                                             0.571429  0.40  0.483179   800
#  3                                             0.750000  0.60  0.700757   497
#  4                                             1.000000  0.80  0.998782  5063
# street_number_trigram
#                           street_number_trigram
#                                             max  min      mean  size
# street_number_trigram_bin
# -1                                          NaN  NaN       NaN  3487
#  0                                     0.181818  0.0  0.072162   189
#  1                                     0.375000  0.2  0.271602  1053
#  2                                     0.571429  0.4  0.445954   239
#  4                                     1.000000  1.0  1.000000  5032
# ############## Pipeline   1 Finished (10000, 26)
# ############## Pipeline  2 Start (10000, 26) pd_col_to_onehot
# name_levenshtein_simple_bin 5 (10000, 26)
# name_trigram_simple_bin 5 (10000, 30)
# name_levenshtein_term_bin 5 (10000, 34)
# name_trigram_term_bin 5 (10000, 38)
# city_levenshtein_simple_bin 6 (10000, 42)
# city_trigram_simple_bin 6 (10000, 47)
# city_levenshtein_term_bin 6 (10000, 52)
# city_trigram_term_bin 6 (10000, 57)
# zip_levenshtein_simple_bin 6 (10000, 62)
# zip_trigram_simple_bin 6 (10000, 67)
# zip_levenshtein_term_bin 6 (10000, 72)
# zip_trigram_term_bin 6 (10000, 77)
# street_levenshtein_simple_bin 6 (10000, 82)
# street_trigram_simple_bin 6 (10000, 87)
# street_levenshtein_term_bin 6 (10000, 92)
# street_trigram_term_bin 6 (10000, 97)
# website_levenshtein_simple_bin 6 (10000, 102)
# website_trigram_simple_bin 6 (10000, 107)
# website_levenshtein_term_bin 6 (10000, 112)
# website_trigram_term_bin 6 (10000, 117)
# phone_levenshtein_bin 6 (10000, 122)
# phone_trigram_bin 6 (10000, 127)
# fax_levenshtein_bin 6 (10000, 132)
# fax_trigram_bin 6 (10000, 137)
# street_number_levenshtein_bin 6 (10000, 142)
# street_number_trigram_bin 5 (10000, 147)
# ############## Pipeline   2 Finished (10000, 151)
#                name_levenshtein_simple_bin_0  ...  street_number_trigram_bin_4
# id                                            ...
# 1204#1207                                  0  ...                            1
# 1272#1279                                  0  ...                            1
# 6258#6259                                  0  ...                            1
# 16076#16077                                0  ...                            0
# 2666#2671                                  0  ...                            1
# 4402#4403                                  0  ...                            1
# 4025#4028                                  1  ...                            0
# 4126#4138                                  0  ...                            0
# 4559#4560                                  1  ...                            0
# 15610#15611                                0  ...                            0
# 7068#7070                                  0  ...                            1
# 8946#8941                                  0  ...                            1
# 362#367                                    0  ...                            0
# 1388#1377                                  0  ...                            0
# 2604#2606                                  0  ...                            0
# 2083#2086                                  1  ...                            1
# 1690#1692                                  0  ...                            0
# 185#187                                    0  ...                            1
# 2710#2715                                  0  ...                            0
# 1229#1239                                  1  ...                            1
# 3532#3536                                  1  ...                            0
# 8983#9003                                  0  ...                            1
# 8541#8542                                  0  ...                            0
# 3687#3706                                  1  ...                            0
# 2343#2347                                  0  ...                            1
# 9937#9938                                  1  ...                            0
# 2894#2900                                  0  ...                            1
# 224843#522528                              1  ...                            0
# 1725#1730                                  0  ...                            1
# 3562#3640                                  1  ...                            0
# ...                                      ...  ...                          ...
# 3561#3638                                  1  ...                            0
# 1833#1838                                  0  ...                            1
# 12239#11861                                0  ...                            0
# 2511#2522                                  0  ...                            0
# 1665#1666                                  1  ...                            1
# 8793#8795                                  0  ...                            1
# 954#959                                    0  ...                            1
# 1125#1138                                  0  ...                            1
# 9047#9050                                  0  ...                            1
# 2473#2464                                  0  ...                            1
# 2350#2353                                  0  ...                            0
# 8198#8192                                  1  ...                            0
# 6#208                                      1  ...                            0
# 12757#12824                                0  ...                            0
# 2310#2312                                  1  ...                            0
# 10374#10375                                1  ...                            0
# 10568#10569                                1  ...                            0
# 8850#8848                                  0  ...                            1
# 15324#15305                                1  ...                            1
# 1047#1051                                  0  ...                            1
# 662#670                                    0  ...                            1
# 6574#6576                                  0  ...                            1
# 12607#12608                                0  ...                            0
# 6906#6907                                  0  ...                            1
# 8467#8468                                  0  ...                            0
# 11137#11138                                0  ...                            0
# 7103#7105                                  0  ...                            0
# 8777#8778                                  0  ...                            0
# 9077#9081                                  0  ...                            1
# 1515#1522                                  0  ...                            1
#
# [10000 rows x 151 columns]

# %% [markdown]
# ## Colcat

# %%
dfcat_hot, colcat_onehot = util_feature.pd_col_to_onehot(df[colcat], colname=colcat,  
                                         colonehot=None, return_val="dataframe,param")
dfcat_hot[colcat_onehot ].head(5)
# Out:
# phone_equality 3 (28235, 3)
# fax_equality 3 (28235, 5)
# street_number_equality 3 (28235, 7)
#              phone_equality_m  ...  street_number_equality_s
# id                             ...
# 1204#1207                   1  ...                         1
# 1272#1279                   1  ...                         1
# 6258#6259                   0  ...                         1
# 16076#16077                 0  ...                         0
# 2666#2671                   0  ...                         1
#
# [5 rows x 9 columns]

# %%
print("Final features")

dfnum_hot.head(3) 
dfcat_hot.head(3)
# Out:
# Final features
#            phone_equality_m  ...  street_number_equality_s
# id                           ...
# 1204#1207                 1  ...                         1
# 1272#1279                 1  ...                         1
# 6258#6259                 0  ...                         1
#
# [3 rows x 9 columns]

# %%
## To pipeline
#  Save each feature processing into "Reproductible pipeline".
#  For Scalability, for repreoduction process
#  Can be easily re-factored for PySpark )
pipe_preprocess_colcat =[ 
           (util_feature.pd_col_fillna, {"value": "-1", "method" : "",   "return_val": "dataframe" },
           )        

          ,(util_feature.pd_col_to_onehot, { "colname": None,  "colonehot": colcat_onehot,  
                                "return_val": "dataframe"  } , "convert to one hot")
]


###Check pipeline
util_feature.pd_pipeline_apply( df[colcat].iloc[:10,:], pipe_preprocess_colcat)
# Out:
# ############## Pipeline  0 Start (10, 3) pd_col_fillna
# phone_equality 0 replaceBY -1
# fax_equality 0 replaceBY -1
# street_number_equality 0 replaceBY -1
# ############## Pipeline   0 Finished (10, 3)
# ############## Pipeline  1 Start (10, 3) pd_col_to_onehot
# phone_equality 2 (10, 3)
# fax_equality 1 (10, 3)
# street_number_equality 2 (10, 3)
# phone_equality_m added
# phone_equality_n added
# phone_equality_s added
# fax_equality_m added
# fax_equality_n added
# fax_equality_s added
# street_number_equality_m added
# street_number_equality_n added
# street_number_equality_s added
# ############## Pipeline   1 Finished (10, 9)
#              phone_equality_m  ...  street_number_equality_s
# id                             ...
# 1204#1207                   0  ...                         0
# 1272#1279                   0  ...                         0
# 6258#6259                   0  ...                         0
# 16076#16077                 0  ...                         0
# 2666#2671                   0  ...                         0
# 4402#4403                   0  ...                         0
# 4025#4028                   0  ...                         0
# 4126#4138                   0  ...                         0
# 4559#4560                   0  ...                         0
# 15610#15611                 0  ...                         0
#
# [10 rows x 9 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-f5e9d059b696> in <module>
#       4            (pd_col_to_num,   {"default": np.nan,} , "Conver string to NA")
#       5
# ----> 6           ,(pd_colnum_tocat, { "colname":None, "colbinmap": colnum_binmap,  'bins': 5,
#       7                                "method": "uniform", "suffix":"_bin", "return_val": "dataframe"},
#       8                                "Convert Numerics to Category " )
#
# NameError: name 'colnum_binmap' is not defined

# %% [markdown]
# ## Coltext

# %% [markdown]
# ## Coldate

# %% [markdown]
# # Pre-Feature Selection

# %% [markdown]
# # Train data preparation

# %%
#### Train data preparation
from sklearn.model_selection import (GridSearchCV, cross_val_score,
                                     train_test_split)

dfX = pd.concat(( dfnum_hot, dfcat_hot ), axis=1)
colX = list( dfX.columns )

dfy = df[coly]
#X  = dfX.values
#yy = df[coly].values

Xtrain, Xtest, ytrain, ytest = train_test_split( dfX,  dfy,   
                                                 random_state=42,
                                                 test_size=0.5, shuffle=True)


print( Xtrain.shape, Xtest.shape, colX)
# Out:
# (14117, 160) (14118, 160) ['name_levenshtein_simple_bin_0', 'name_levenshtein_simple_bin_1', 'name_levenshtein_simple_bin_2', 'name_levenshtein_simple_bin_3', 'name_levenshtein_simple_bin_4', 'name_trigram_simple_bin_0', 'name_trigram_simple_bin_1', 'name_trigram_simple_bin_2', 'name_trigram_simple_bin_3', 'name_trigram_simple_bin_4', 'name_levenshtein_term_bin_0', 'name_levenshtein_term_bin_1', 'name_levenshtein_term_bin_2', 'name_levenshtein_term_bin_3', 'name_levenshtein_term_bin_4', 'name_trigram_term_bin_0', 'name_trigram_term_bin_1', 'name_trigram_term_bin_2', 'name_trigram_term_bin_3', 'name_trigram_term_bin_4', 'city_levenshtein_simple_bin_-1', 'city_levenshtein_simple_bin_0', 'city_levenshtein_simple_bin_1', 'city_levenshtein_simple_bin_2', 'city_levenshtein_simple_bin_3', 'city_levenshtein_simple_bin_4', 'city_trigram_simple_bin_-1', 'city_trigram_simple_bin_0', 'city_trigram_simple_bin_1', 'city_trigram_simple_bin_2', 'city_trigram_simple_bin_3', 'city_trigram_simple_bin_4', 'city_levenshtein_term_bin_-1', 'city_levenshtein_term_bin_0', 'city_levenshtein_term_bin_1', 'city_levenshtein_term_bin_2', 'city_levenshtein_term_bin_3', 'city_levenshtein_term_bin_4', 'city_trigram_term_bin_-1', 'city_trigram_term_bin_0', 'city_trigram_term_bin_1', 'city_trigram_term_bin_2', 'city_trigram_term_bin_3', 'city_trigram_term_bin_4', 'zip_levenshtein_simple_bin_-1', 'zip_levenshtein_simple_bin_0', 'zip_levenshtein_simple_bin_1', 'zip_levenshtein_simple_bin_2', 'zip_levenshtein_simple_bin_3', 'zip_levenshtein_simple_bin_4', 'zip_trigram_simple_bin_-1', 'zip_trigram_simple_bin_0', 'zip_trigram_simple_bin_1', 'zip_trigram_simple_bin_2', 'zip_trigram_simple_bin_3', 'zip_trigram_simple_bin_4', 'zip_levenshtein_term_bin_-1', 'zip_levenshtein_term_bin_0', 'zip_levenshtein_term_bin_1', 'zip_levenshtein_term_bin_2', 'zip_levenshtein_term_bin_3', 'zip_levenshtein_term_bin_4', 'zip_trigram_term_bin_-1', 'zip_trigram_term_bin_0', 'zip_trigram_term_bin_1', 'zip_trigram_term_bin_2', 'zip_trigram_term_bin_3', 'zip_trigram_term_bin_4', 'street_levenshtein_simple_bin_-1', 'street_levenshtein_simple_bin_0', 'street_levenshtein_simple_bin_1', 'street_levenshtein_simple_bin_2', 'street_levenshtein_simple_bin_3', 'street_levenshtein_simple_bin_4', 'street_trigram_simple_bin_-1', 'street_trigram_simple_bin_0', 'street_trigram_simple_bin_1', 'street_trigram_simple_bin_2', 'street_trigram_simple_bin_3', 'street_trigram_simple_bin_4', 'street_levenshtein_term_bin_-1', 'street_levenshtein_term_bin_0', 'street_levenshtein_term_bin_1', 'street_levenshtein_term_bin_2', 'street_levenshtein_term_bin_3', 'street_levenshtein_term_bin_4', 'street_trigram_term_bin_-1', 'street_trigram_term_bin_0', 'street_trigram_term_bin_1', 'street_trigram_term_bin_2', 'street_trigram_term_bin_3', 'street_trigram_term_bin_4', 'website_levenshtein_simple_bin_-1', 'website_levenshtein_simple_bin_0', 'website_levenshtein_simple_bin_1', 'website_levenshtein_simple_bin_2', 'website_levenshtein_simple_bin_3', 'website_levenshtein_simple_bin_4', 'website_trigram_simple_bin_-1', 'website_trigram_simple_bin_0', 'website_trigram_simple_bin_1', 'website_trigram_simple_bin_2', 'website_trigram_simple_bin_3', 'website_trigram_simple_bin_4', 'website_levenshtein_term_bin_-1', 'website_levenshtein_term_bin_0', 'website_levenshtein_term_bin_1', 'website_levenshtein_term_bin_2', 'website_levenshtein_term_bin_3', 'website_levenshtein_term_bin_4', 'website_trigram_term_bin_-1', 'website_trigram_term_bin_0', 'website_trigram_term_bin_1', 'website_trigram_term_bin_2', 'website_trigram_term_bin_3', 'website_trigram_term_bin_4', 'phone_levenshtein_bin_-1', 'phone_levenshtein_bin_0', 'phone_levenshtein_bin_1', 'phone_levenshtein_bin_2', 'phone_levenshtein_bin_3', 'phone_levenshtein_bin_4', 'phone_trigram_bin_-1', 'phone_trigram_bin_0', 'phone_trigram_bin_1', 'phone_trigram_bin_2', 'phone_trigram_bin_3', 'phone_trigram_bin_4', 'fax_levenshtein_bin_-1', 'fax_levenshtein_bin_0', 'fax_levenshtein_bin_1', 'fa ...

# %%
0
# Out:
# 0

# %% [markdown]
# # Model evaluation

# %% [markdown]
# ## Baseline : Logistic L2 penalty

# %%
import sklearn as sk
clf_log = sk.linear_model.LogisticRegression(penalty = 'l2' , class_weight = 'balanced')

# %%
clf_log, clf_log_stats = util_model.sk_model_eval_classification(clf_log, 1,
                                           Xtrain, ytrain, Xtest, ytest)
# Out:
# ############# Train dataset  ####################################
# Test confusion matrix
# [[3778  263]
#  [ 711 9365]]
# [[0.9349171  0.0650829 ]
#  [0.07056372 0.92943628]]
# auc 0.9823526793990026
# gini 0.9647053587980052
# acc 0.9310051710703408
# f1macro 0.9181915919500756
# Nsample 14117
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.89      4041
#            1       0.97      0.93      0.95     10076
#
#    micro avg       0.93      0.93      0.93     14117
#    macro avg       0.91      0.93      0.92     14117
# weighted avg       0.94      0.93      0.93     14117
# ############# Test dataset  #########################################
# Test confusion matrix
# [[3662  270]
#  [ 745 9441]]
# [[0.93133266 0.06866734]
#  [0.0731396  0.9268604 ]]
# auc 0.9816998312566328
# gini 0.9633996625132657
# acc 0.9281059640175662
# f1macro 0.9136350261166026
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      3932
#            1       0.97      0.93      0.95     10186
#
#    micro avg       0.93      0.93      0.93     14118
#    macro avg       0.90      0.93      0.91     14118
# weighted avg       0.93      0.93      0.93     14118

# %%
clf_log, dd = sk_model_eval_classification(clf_log, 1,
                                           Xtrain, ytrain, Xtest, ytest)

# %%
util_model.sk_model_eval_classification_cv(clf_log,  dfX, dfy, test_size=0.5, ncv=3 )
# Out:
# ############# CV-0######################################
# ############# Train dataset  ####################################
# Test confusion matrix
# [[3739  254]
#  [ 714 9410]]
# [[0.93638868 0.06361132]
#  [0.07052548 0.92947452]]
# auc 0.9823131437146575
# gini 0.964626287429315
# acc 0.9314301905504002
# f1macro 0.9182354985101129
# Nsample 14117
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      3993
#            1       0.97      0.93      0.95     10124
#
#    micro avg       0.93      0.93      0.93     14117
#    macro avg       0.91      0.93      0.92     14117
# weighted avg       0.94      0.93      0.93     14117
# ############# Test dataset  #########################################
# Test confusion matrix
# [[3693  287]
#  [ 693 9445]]
# [[0.92788945 0.07211055]
#  [0.06835668 0.93164332]]
# auc 0.981788244338679
# gini 0.9635764886773579
# acc 0.9305850687066156
# f1macro 0.9167693040864111
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88      3980
#            1       0.97      0.93      0.95     10138
#
#    micro avg       0.93      0.93      0.93     14118
#    macro avg       0.91      0.93      0.92     14118
# weighted avg       0.93      0.93      0.93     14118
# ############# CV-1######################################
# ############# Train dataset  ####################################
# Test confusion matrix
# [[3736  232]
#  [ 802 9347]]
# [[0.94153226 0.05846774]
#  [0.07902256 0.92097744]]
# auc 0.9818035862424074
# gini 0.9636071724848148
# acc 0.9267549762697457
# f1macro 0.9130129674220707
# Nsample 14117
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88      3968
#            1       0.98      0.92      0.95     10149
#
#    micro avg       0.93      0.93      0.93     14117
#    macro avg       0.90      0.93      0.91     14117
# weighted avg       0.93      0.93      0.93     14117
# ############# Test dataset  #########################################
# Test confusion matrix
# [[3773  232]
#  [ 815 9298]]
# [[0.94207241 0.05792759]
#  [0.08058934 0.91941066]]
# auc 0.9824402479201009
# gini 0.9648804958402017
# acc 0.9258393540161496
# f1macro 0.9124276042949092
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88      4005
#            1       0.98      0.92      0.95     10113
#
#    micro avg       0.93      0.93      0.93     14118
#    macro avg       0.90      0.93      0.91     14118
# weighted avg       0.93      0.93      0.93     14118
# ############# CV-2######################################
# ############# Train dataset  ####################################
# Test confusion matrix
# [[3710  251]
#  [ 669 9487]]
# [[0.93663216 0.06336784]
#  [0.06587239 0.93412761]]
# auc 0.9832689070942676
# gini 0.9665378141885352
# acc 0.9348303463908763
# f1macro 0.9217215751878239
# Nsample 14117
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      3961
#            1       0.97      0.93      0.95     10156
#
#    micro avg       0.93      0.93      0.93     14117
#    macro avg       0.91      0.94      0.92     14117
# weighted avg       0.94      0.93      0.94     14117
# ############# Test dataset  #########################################
# Test confusion matrix
# [[3724  288]
#  [ 736 9370]]
# [[0.92821535 0.07178465]
#  [0.07282802 0.92717198]]
# auc 0.9806621842369192
# gini 0.9613243684738384
# acc 0.9274684799546677
# f1macro 0.9136599408430243
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      4012
#            1       0.97      0.93      0.95     10106
#
#    micro avg       0.93      0.93      0.93     14118
#    macro avg       0.90      0.93      0.91     14118
# weighted avg       0.93      0.93      0.93     14118
# {0: LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#            solver='warn', tol=0.0001, verbose=0, warm_start=False),
#  1: LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#            solver='warn', tol=0.0001, verbose=0, warm_start=False),
#  2: LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#            solver='warn', tol=0.0001, verbose=0, warm_start=False)}

# %%
clf_log_feat = sk_feature_impt_logis(clf_log, colX)
clf_log_feat.head(20)
# Out:
#                              feature      coef  coef_abs  rank
# 141  street_number_levenshtein_bin_0 -2.358337  2.358337     0
# 15           name_trigram_term_bin_0 -2.137965  2.137965     1
# 5          name_trigram_simple_bin_0 -2.093382  2.093382     2
# 87         street_trigram_term_bin_0 -2.021471  2.021471     3
# 126              phone_trigram_bin_3  1.977571  1.977571     4
# 9          name_trigram_simple_bin_4  1.926667  1.926667     5
# 18           name_trigram_term_bin_3  1.574609  1.574609     6
# 28         city_trigram_simple_bin_1  1.560024  1.560024     7
# 145  street_number_levenshtein_bin_4  1.502074  1.502074     8
# 127              phone_trigram_bin_4  1.466875  1.466875     9
# 153                 phone_equality_2  1.466875  1.466875    10
# 124              phone_trigram_bin_1 -1.179984  1.179984    11
# 159         street_number_equality_2  1.166209  1.166209    12
# 150      street_number_trigram_bin_4  1.166209  1.166209    13
# 54          zip_trigram_simple_bin_3  1.164872  1.164872    14
# 148      street_number_trigram_bin_1 -1.158046  1.158046    15
# 114       website_trigram_term_bin_3  1.123416  1.123416    16
# 39           city_trigram_term_bin_0 -1.068346  1.068346    17
# 152                 phone_equality_1 -1.066404  1.066404    18
# 90         street_trigram_term_bin_3  0.963100  0.963100    19

# %%
clf_log_stats
# Out:
# {'ytest_pred': array([ 1, -1, -1, ...,  1,  1,  1], dtype=int64)}

# %% [markdown]
# ## Light GBM

# %%
clf_lgb = lgb.LGBMClassifier(learning_rate = 0.125, metric = 'l2', 
                         max_depth= 15, n_estimators = 50, objective= 'binary',
                         num_leaves = 38, njobs= -1 )

# %%
clf_lgb, clf_lgb_stats  = util_model.sk_model_eval_classification(clf_lgb, 1,
                                           Xtrain, ytrain, Xtest, ytest)
# Out:
# ############# Train dataset  ####################################
# Test confusion matrix
# [[3665  376]
#  [ 311 9765]]
# [[0.90695372 0.09304628]
#  [0.03086542 0.96913458]]
# auc 0.9893972475850205
# gini 0.9787944951700409
# acc 0.9513352695331869
# f1macro 0.9401628972770302
# Nsample 14117
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      4041
#            1       0.96      0.97      0.97     10076
#
#    micro avg       0.95      0.95      0.95     14117
#    macro avg       0.94      0.94      0.94     14117
# weighted avg       0.95      0.95      0.95     14117
# ############# Test dataset  #########################################
# Test confusion matrix
# [[3496  436]
#  [ 381 9805]]
# [[0.88911495 0.11088505]
#  [0.03740428 0.96259572]]
# auc 0.984503906384983
# gini 0.969007812769966
# acc 0.9421306134013316
# f1macro 0.9276905226694739
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      3932
#            1       0.96      0.96      0.96     10186
#
#    micro avg       0.94      0.94      0.94     14118
#    macro avg       0.93      0.93      0.93     14118
# weighted avg       0.94      0.94      0.94     14118

# %%
import shap
shap.initjs()

#dftest = pd.DataFrame( columns=colX, data=Xtest)

explainer = shap.TreeExplainer( clf_lgb )
shap_values = explainer.shap_values(  Xtest )


# visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
shap.force_plot(explainer.expected_value, shap_values[0,:], Xtest.iloc[0,:] )
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# <div id='iUA9549IQTZ4WF5I42AHY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 2.5734227446934184, "outValue": 6.3855988812998845, "link": "identity", "featureNames": ["name_levenshtein_simple_bin_0", "name_levenshtein_simple_bin_1", "name_levenshtein_simple_bin_2", "name_levenshtein_simple_bin_3", "name_levenshtein_simple_bin_4", "name_trigram_simple_bin_0", "name_trigram_simple_bin_1", "name_trigram_simple_bin_2", "name_trigram_simple_bin_3", "name_trigram_simple_bin_4", "name_levenshtein_term_bin_0", "name_levenshtein_term_bin_1", "name_levenshtein_term_bin_2", "name_levenshtein_term_bin_3", "name_levenshtein_term_bin_4", "name_trigram_term_bin_0", "name_trigram_term_bin_1", "name_trigram_term_bin_2", "name_trigram_term_bin_3", "name_trigram_term_bin_4", "city_levenshtein_simple_bin_-1", "city_levenshtein_simple_bin_0", "city_levenshtein_simple_bin_1", "city_levenshtein_simple_bin_2", "city_levenshtein_simple_bin_3", "city_levenshtein_simple_bin_4", "city_trigram_simple_bin_-1", "city_trigram_simple_bin_0", "city_trigram_simple_bin_1", "city_trigram_simple_bin_2", "city_trigram_simple_bin_3", "city_trigram_simple_bin_4", "city_levenshtein_term_bin_-1", "city_levenshtein_term_bin_0", "city_levenshtein_term_bin_1", "city_levenshtein_term_bin_2", "city_levenshtein_term_bin_3", "city_levenshtein_term_bin_4", "city_trigram_term_bin_-1", "city_trigram_term_bin_0", "city_trigram_term_bin_1", "city_trigram_term_bin_2", "city_trigram_term_bin_3", "city_trigram_term_bin_4", "zip_levenshtein_simple_bin_-1", "zip_levenshtein_simple_bin_0", "zip_levenshtein_simple_bin_1", "zip_levenshtein_simple_bin_2", "zip_levenshtein_simple_bin_3", "zip_levenshtein_simple_bin_4", "zip_trigram_simple_bin_-1", "zip_trigram_simple_bin_0", "zip_trigram_simple_bin_1", "zip_trigram_simple_bin_2", "zip_trigram_simple_bin_3", "zip_trigram_simple_bin_4", "zip_levenshtein_term_bin_-1", "zip_levenshtein_term_bin_0", "zip_levenshtein_term_bin_1", "zip_levenshtein_term_bin_2", "zip_levenshtein_term_bin_3", "zip_levenshtein_term_bin_4", "zip_trigram_term_bin_-1", "zip_trigram_term_bin_0", "zip_trigram_term_bin_1", "zip_trigram_term_bin_2", "zip_trigram_term_bin_3", "zip_trigram_term_bin_4", "street_levenshtein_simple_bin_-1", "street_levenshtein_simple_bin_0", "street_levenshtein_simple_bin_1", "street_levenshtein_simple_bin_2", "street_levenshtein_simple_bin_3", "street_levenshtein_simple_bin_4", "street_trigram_simple_bin_-1", "street_trigram_simple_bin_0", "street_trigram_simple_bin_1", "street_trigram_simple_bin_2", "street_trigram_simple_bin_3", "street_trigram_simple_bin_4", "street_levenshtein_term_bin_-1", "street_levenshtein_term_bin_0", "street_levenshtein_term_bin_1", "street_levenshtein_term_bin_2", "street_levenshtein_term_bin_3", "street_levenshtein_term_bin_4", "street_trigram_term_bin_-1", "street_trigram_term_bin_0", "street_trigram_term_bin_1", "street_trigram_term_bin_2", "street_trigram_term_bin_3", "street_trigram_term_bin_4", "website_levenshtein_simple_bin_-1", "website_levenshtein_simple_bin_0", "website_levenshtein_simple_bin_1", "website_levenshtein_simple_bin_2", "website_levenshtein_simple_bin_3", "website_levenshtein_simple_bin_4", "website_trigram_simple_bin_-1", "website_trigram_simple_bin_0", "website_trigram_simple_bin_1", "website_trigram_simple_bin_2", "website_trigram_simple_bin_3", "website_trigram_simple_bin_4", "website_levenshtein_term_bin_-1", "website_levenshtein_term_bin_0", "website_levenshtein_term_bin_1", "website_levenshtein_term_bin_2", "website_levenshtein_term_bin_3", "website_levenshtein_term_bin_4", "website_trigram_term_bin_-1", "website_trigram_term_bin_0", "website_trigram_term_bin_1", "website_trigram_term_bin_2", "website_trigram_term_bin_3", "website_trigram_term_bin_4", "phone_levenshtein_bin_-1", "phone_levenshtein_bin_0", "phone_levenshtein_bin_1", "phone_levenshtein_bin_2", "phone_levenshtein_bin_3", "phone_levenshtein_bin_4", "phone_trigram_bin_-1", "phone_trigram_bin_0", "phone ...

# %%
# Plot summary_plot as barplot:
shap.summary_plot(shap_values, Xtest)

# %%
# visualize the training set predictions
shap.dependence_plot("name_trigram_term_bin_0", shap_values, Xtest.iloc[:,:]  )

# %%
kf = StratifiedKFold(n_splits=3, shuffle=True)
# partially based on https://www.kaggle.com/c0conuts/xgb-k-folds-fastai-pca
clf_list = []
for itrain, itest in kf.split(X, yy):
    print("###")
    Xtrain, Xval = X[ itrain ], X[ itest ]
    ytrain, yval = yy[ itrain ], yy[ itest ]
    clf_lgb.fit(Xtrain, ytrain, eval_set=[(Xval, yval)], 
            early_stopping_rounds=20)
    
    
    clf_list.append( clf_lgb)
    
    

    
lgb_feature_imp2 = util_model.sk_feature_impt(clf_lgb, colname= colall, model_type="lgb")
# Out:
# ###
# [1]	valid_0's l2: 0.165652
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's l2: 0.138458
# [3]	valid_0's l2: 0.117709
# [4]	valid_0's l2: 0.101755
# [5]	valid_0's l2: 0.0894591
# [6]	valid_0's l2: 0.0800007
# [7]	valid_0's l2: 0.0726722
# [8]	valid_0's l2: 0.0668097
# [9]	valid_0's l2: 0.0622689
# [10]	valid_0's l2: 0.0587631
# [11]	valid_0's l2: 0.0557934
# [12]	valid_0's l2: 0.0534385
# [13]	valid_0's l2: 0.0516411
# [14]	valid_0's l2: 0.05025
# [15]	valid_0's l2: 0.0490479
# [16]	valid_0's l2: 0.0481288
# [17]	valid_0's l2: 0.0473454
# [18]	valid_0's l2: 0.0466832
# [19]	valid_0's l2: 0.0460093
# [20]	valid_0's l2: 0.0456373
# [21]	valid_0's l2: 0.0452697
# [22]	valid_0's l2: 0.0449898
# [23]	valid_0's l2: 0.0447381
# [24]	valid_0's l2: 0.0444604
# [25]	valid_0's l2: 0.0441435
# [26]	valid_0's l2: 0.043848
# [27]	valid_0's l2: 0.0436615
# [28]	valid_0's l2: 0.0434046
# [29]	valid_0's l2: 0.0432684
# [30]	valid_0's l2: 0.043172
# [31]	valid_0's l2: 0.0429087
# [32]	valid_0's l2: 0.0428253
# [33]	valid_0's l2: 0.0427235
# [34]	valid_0's l2: 0.0426134
# [35]	valid_0's l2: 0.042499
# [36]	valid_0's l2: 0.0423915
# [37]	valid_0's l2: 0.0422781
# [38]	valid_0's l2: 0.0422483
# [39]	valid_0's l2: 0.0421505
# [40]	valid_0's l2: 0.0421353
# [41]	valid_0's l2: 0.042056
# [42]	valid_0's l2: 0.0420583
# [43]	valid_0's l2: 0.0420423
# [44]	valid_0's l2: 0.0419342
# [45]	valid_0's l2: 0.0418067
# [46]	valid_0's l2: 0.0417043
# [47]	valid_0's l2: 0.0416708
# [48]	valid_0's l2: 0.0416179
# [49]	valid_0's l2: 0.0415353
# [50]	valid_0's l2: 0.041493
# Did not meet early stopping. Best iteration is:
# [50]	valid_0's l2: 0.041493
# ###
# [1]	valid_0's l2: 0.1652
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's l2: 0.137679
# [3]	valid_0's l2: 0.117023
# [4]	valid_0's l2: 0.101256
# [5]	valid_0's l2: 0.0891785
# [6]	valid_0's l2: 0.0798097
# [7]	valid_0's l2: 0.0724888
# [8]	valid_0's l2: 0.0666746
# [9]	valid_0's l2: 0.0621351
# [10]	valid_0's l2: 0.0586854
# [11]	valid_0's l2: 0.0559126
# [12]	valid_0's l2: 0.0537049
# [13]	valid_0's l2: 0.0520906
# [14]	valid_0's l2: 0.0507025
# [15]	valid_0's l2: 0.0496651
# [16]	valid_0's l2: 0.0487514
# [17]	valid_0's l2: 0.0480066
# [18]	valid_0's l2: 0.0473729
# [19]	valid_0's l2: 0.0468727
# [20]	valid_0's l2: 0.0464998
# [21]	valid_0's l2: 0.0461135
# [22]	valid_0's l2: 0.0458133
# [23]	valid_0's l2: 0.0455605
# [24]	valid_0's l2: 0.0452672
# [25]	valid_0's l2: 0.0450351
# [26]	valid_0's l2: 0.0448099
# [27]	valid_0's l2: 0.044615
# [28]	valid_0's l2: 0.0444128
# [29]	valid_0's l2: 0.0442498
# [30]	valid_0's l2: 0.0440897
# [31]	valid_0's l2: 0.0439524
# [32]	valid_0's l2: 0.0439067
# [33]	valid_0's l2: 0.0438085
# [34]	valid_0's l2: 0.0437132
# [35]	valid_0's l2: 0.0435839
# [36]	valid_0's l2: 0.0434712
# [37]	valid_0's l2: 0.0433675
# [38]	valid_0's l2: 0.0433562
# [39]	valid_0's l2: 0.0432841
# [40]	valid_0's l2: 0.0431997
# [41]	valid_0's l2: 0.043181
# [42]	valid_0's l2: 0.0431731
# [43]	valid_0's l2: 0.0430786
# [44]	valid_0's l2: 0.0430205
# [45]	valid_0's l2: 0.0430149
# [46]	valid_0's l2: 0.0429823
# [47]	valid_0's l2: 0.0430153
# [48]	valid_0's l2: 0.0429784
# [49]	valid_0's l2: 0.0429015
# [50]	valid_0's l2: 0.04283
# Did not meet early stopping. Best iteration is:
# [50]	valid_0's l2: 0.04283
# ###
# [1]	valid_0's l2: 0.164899
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's l2: 0.137195
# [3]	valid_0's l2: 0.116368
# [4]	valid_0's l2: 0.100556
# [5]	valid_0's l2: 0.0882384
# [6]	valid_0's l2: 0.0788355
# [7]	valid_0's l2: 0.0713484
# [8]	valid_0's l2: 0.0655519
# [9]	valid_0's l2: 0.0610337
# [10]	valid_0's l2: 0.0575115
# [11]	valid_0's l2: 0.0547956
# [12]	valid_0's l2: 0.0526633
# [13]	valid_0's l2: 0.0509664
# [14]	valid_0's l2: 0.0496073
# [15]	valid_0's l2: 0.0484997
# [16]	valid_0's l2: 0.0476139
# [17]	valid_0's l2: 0.0468199
# [18]	valid_0's l2: 0.0461802
# [19]	valid_0's l2: 0.0457658
# [20]	valid_0's l2: 0.0452722
# [21]	valid_0's l2: 0.0448226
# [22]	valid_0's l2: 0.0445112
# [23]	valid_0's l2: 0.0441861
# [24]	valid_0's l2: 0.0438997
# [25]	valid_0's l2: 0.0436824
# [26]	valid_0's l2: 0.0435145
# [27]	valid_0's l2: 0.0433422
# [28]	valid_0's l2: 0.0431507
# [29]	valid_0's l2: 0.0430532
# [30]	valid_0's l2: 0.0429276
# [31]	valid_0's l2: 0.0428085
# [32]	valid_0's l2: 0.0427481
# [33]	valid_0's l2: 0.0426234
# [34]	valid_0's l2: 0.0424868
# [35]	valid_0's l2: 0.0424261
# [36]	valid_0's l2: 0.0423334
# [37]	valid_0's l2: 0.0422816
# [38]	valid_0's l2: 0.0421767
# [39]	valid_0's l2: 0.0421224
# [40]	valid_0's l2: 0.0420711
# [41]	valid_0's l2: 0.0420169
# [42]	valid_0's l2: 0.0419998
# [43]	valid_0's l2: 0.0419318
# [44]	valid_0's l2: 0.0419013
# [45]	valid_0's l2: 0.0418576
# [46]	valid_0's l2: 0.0418484
# [47]	valid_0's l2: 0.0417541
# [48]	valid_0's l2: 0.0416978
# [49]	valid_0's l2: 0.0417362
# [50]	valid_0's l2: 0.0417077
# Did not meet early stopping. Best iteration is:
# [48]	valid_0's l2: 0.0416978
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-262-055ee6181285> in <module>
#      15
#      16
# ---> 17 lgb_feature_imp2 = util_model.sk_feature_impt(clf_lgb, colname= colall, model_type="lgb")
#      18
#      19
#
# TypeError: sk_feature_impt() got an unexpected keyword argument 'model_type'

# %%
lgb_feature_imp = util_model.sk_feature_impt(clf_lgb.feature_importances_, colname= colX, model_type="lgb")


util_plot.plotbar(lgb_feature_imp.iloc[:10,:], colname=["col", "weight"],  
                  title="feature importance", savefile="lgb_feature_imp.png")

# %%
for i, clfi in enumerate( clf_list) :
    print(i)
    clf_lgbi, dd_lgbi = sk_model_eval_classification(clfi, 0,
                                               Xtrain, ytrain, Xtest, ytest)
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-41-a444f1f27ec2>", line 1, in <module>
#     for i, clfi in enumerate( clf_list) :
#
# NameError: name 'clf_list' is not defined

# %% [markdown]
# ## SVM

# %%
clf_svc = SVC(C=1.0, probability=True) # since we need probabilities

clf_svc, clf_svc_stats = util_model.sk_model_eval_classification(clf_svc, 1,
                                               Xtrain, ytrain, Xtest, ytest)
# Out:
# ############# Train dataset  ####################################
# Test confusion matrix
# [[3480  561]
#  [ 362 9714]]
# [[0.86117298 0.13882702]
#  [0.03592696 0.96407304]]
# auc 0.9807684316344998
# gini 0.9615368632689996
# acc 0.9346178366508465
# f1macro 0.9187792800352295
# Nsample 14117
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88      4041
#            1       0.95      0.96      0.95     10076
#
#    micro avg       0.93      0.93      0.93     14117
#    macro avg       0.93      0.91      0.92     14117
# weighted avg       0.93      0.93      0.93     14117
# ############# Test dataset  #########################################
# Test confusion matrix
# [[3380  552]
#  [ 379 9807]]
# [[0.85961343 0.14038657]
#  [0.03720793 0.96279207]]
# auc 0.9801308455205208
# gini 0.9602616910410415
# acc 0.9340558152712849
# f1macro 0.9168171297808874
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88      3932
#            1       0.95      0.96      0.95     10186
#
#    micro avg       0.93      0.93      0.93     14118
#    macro avg       0.92      0.91      0.92     14118
# weighted avg       0.93      0.93      0.93     14118

# %%
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %% [markdown]
# ## Neural Network MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier

clf_nn = MLPClassifier( hidden_layer_sizes=(50,), max_iter=80, alpha=1e-4,
                        activation="relu",
                        solver='adam', verbose=10, tol=1e-4, random_state=1,
                        learning_rate_init= 0.1, early_stopping=True, validation_fraction=0.2 )

# %%
clf_nn, dd_nn = util_model.sk_model_eval_classification(clf_nn, 1,
                                           Xtrain, ytrain, Xtest, ytest)
# Out:
# ############# Train dataset  ####################################
# Iteration 1, loss = 0.30374545
# Validation score: 0.919618
# Iteration 2, loss = 0.15422258
# Validation score: 0.922450
# Iteration 3, loss = 0.15042476
# Validation score: 0.924221
# Iteration 4, loss = 0.14651006
# Validation score: 0.927408
# Iteration 5, loss = 0.14387765
# Validation score: 0.928116
# Iteration 6, loss = 0.13938971
# Validation score: 0.925992
# Iteration 7, loss = 0.13431603
# Validation score: 0.924221
# Iteration 8, loss = 0.13630725
# Validation score: 0.932011
# Iteration 9, loss = 0.13620662
# Validation score: 0.926346
# Iteration 10, loss = 0.13224484
# Validation score: 0.921388
# Iteration 11, loss = 0.13236208
# Validation score: 0.921034
# Iteration 12, loss = 0.12917632
# Validation score: 0.929533
# Iteration 13, loss = 0.12991413
# Validation score: 0.926346
# Iteration 14, loss = 0.12787154
# Validation score: 0.928824
# Iteration 15, loss = 0.12892515
# Validation score: 0.920326
# Iteration 16, loss = 0.12838998
# Validation score: 0.926346
# Iteration 17, loss = 0.12490951
# Validation score: 0.924221
# Iteration 18, loss = 0.12589592
# Validation score: 0.923867
# Iteration 19, loss = 0.12732632
# Validation score: 0.923867
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Test confusion matrix
# [[3642  399]
#  [ 368 9708]]
# [[0.90126206 0.09873794]
#  [0.03652243 0.96347757]]
# auc 0.9859083462591015
# gini 0.971816692518203
# acc 0.9456683431323936
# f1macro 0.9333650261207947
# Nsample 14117
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90      4041
#            1       0.96      0.96      0.96     10076
#
#    micro avg       0.95      0.95      0.95     14117
#    macro avg       0.93      0.93      0.93     14117
# weighted avg       0.95      0.95      0.95     14117
# ############# Test dataset  #########################################
# Test confusion matrix
# [[3490  442]
#  [ 417 9769]]
# [[0.88758901 0.11241099]
#  [0.04093854 0.95906146]]
# auc 0.9810311896587163
# gini 0.9620623793174325
# acc 0.9391556877744723
# f1macro 0.9241528300059735
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      3932
#            1       0.96      0.96      0.96     10186
#
#    micro avg       0.94      0.94      0.94     14118
#    macro avg       0.92      0.92      0.92     14118
# weighted avg       0.94      0.94      0.94     14118

# %% [markdown]
# # Feature selection

# %%
### Feature Selection (reduce over-fitting)
   #Pre model feature selection (sometimes some features are useful even with low variance....)
   #Post model feature selection

# %%
### Model independant Selection
colX_kbest= util_model.sk_model_eval_feature(clf_nn,  method="f_classif", colname= colX, kbest=50,
                                 Xtrain= Xtrain, ytrain= ytrain)


print( colX_kbest )
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-46-9f4c034693d6>", line 2, in <module>
#     colX_kbest= util_model.sk_model_eval_feature(clf_nn,  method="f_classif", colname= colX, kbest=50,
#
# AttributeError: module 'da.util_model' has no attribute 'sk_model_eval_feature'

# %%
clf_log_feat[ :15 ]
# Out:
#                              feature      coef  coef_abs  rank
# 141  street_number_levenshtein_bin_0 -2.358337  2.358337     0
# 15           name_trigram_term_bin_0 -2.137965  2.137965     1
# 5          name_trigram_simple_bin_0 -2.093382  2.093382     2
# 87         street_trigram_term_bin_0 -2.021471  2.021471     3
# 126              phone_trigram_bin_3  1.977571  1.977571     4
# 9          name_trigram_simple_bin_4  1.926667  1.926667     5
# 18           name_trigram_term_bin_3  1.574609  1.574609     6
# 28         city_trigram_simple_bin_1  1.560024  1.560024     7
# 145  street_number_levenshtein_bin_4  1.502074  1.502074     8
# 127              phone_trigram_bin_4  1.466875  1.466875     9
# 153                 phone_equality_2  1.466875  1.466875    10
# 124              phone_trigram_bin_1 -1.179984  1.179984    11
# 159         street_number_equality_2  1.166209  1.166209    12
# 150      street_number_trigram_bin_4  1.166209  1.166209    13
# 54          zip_trigram_simple_bin_3  1.164872  1.164872    14

# %%
clf_log.fit( dfX[colX].values , df[coly].values)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
feat_eval= util_model.sk_feature_evaluation(clf_log, dfX, 30,  
                                 colname_best=clf_log_feat.feature.values, dfy= df[coly] )
# Out:
# (14117, 160) (14117,)
# ########## ['name_trigram_term_bin_0']
# Test confusion matrix
# [[2899 1033]
#  [1001 9185]]
# [[0.73728383 0.26271617]
#  [0.09827214 0.90172786]]
# auc 0.8195058433982453
# gini 0.6390116867964906
# acc 0.8559286017849553
# f1macro 0.8203049423103763
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74      3932
#            1       0.90      0.90      0.90     10186
#
#    micro avg       0.86      0.86      0.86     14118
#    macro avg       0.82      0.82      0.82     14118
# weighted avg       0.86      0.86      0.86     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3']
# Test confusion matrix
# [[2899 1033]
#  [1001 9185]]
# [[0.73728383 0.26271617]
#  [0.09827214 0.90172786]]
# auc 0.8213586647461988
# gini 0.6427173294923976
# acc 0.8559286017849553
# f1macro 0.8203049423103763
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74      3932
#            1       0.90      0.90      0.90     10186
#
#    micro avg       0.86      0.86      0.86     14118
#    macro avg       0.82      0.82      0.82     14118
# weighted avg       0.86      0.86      0.86     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0']
# Test confusion matrix
# [[3113  819]
#  [1101 9085]]
# [[0.79170905 0.20829095]
#  [0.10808953 0.89191047]]
# auc 0.8548047766277653
# gini 0.7096095532555307
# acc 0.8640033999150021
# f1macro 0.8343657811881886
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76      3932
#            1       0.92      0.89      0.90     10186
#
#    micro avg       0.86      0.86      0.86     14118
#    macro avg       0.83      0.84      0.83     14118
# weighted avg       0.87      0.86      0.87     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0']
# Test confusion matrix
# [[3111  821]
#  [1096 9090]]
# [[0.79120041 0.20879959]
#  [0.10759866 0.89240134]]
# auc 0.857992409344883
# gini 0.7159848186897659
# acc 0.8642158946026349
# f1macro 0.8345400040177421
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76      3932
#            1       0.92      0.89      0.90     10186
#
#    micro avg       0.86      0.86      0.86     14118
#    macro avg       0.83      0.84      0.83     14118
# weighted avg       0.87      0.86      0.87     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4']
# Test confusion matrix
# [[3114  818]
#  [1097 9089]]
# [[0.79196338 0.20803662]
#  [0.10769684 0.89230316]]
# auc 0.9000051983263886
# gini 0.8000103966527772
# acc 0.8643575577277235
# f1macro 0.8347609319721139
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76      3932
#            1       0.92      0.89      0.90     10186
#
#    micro avg       0.86      0.86      0.86     14118
#    macro avg       0.83      0.84      0.83     14118
# weighted avg       0.87      0.86      0.87     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1']
# Test confusion matrix
# [[3112  820]
#  [1085 9101]]
# [[0.79145473 0.20854527]
#  [0.10651875 0.89348125]]
# auc 0.9015095420499163
# gini 0.8030190840998326
# acc 0.8650658733531662
# f1macro 0.835455353837288
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.77      3932
#            1       0.92      0.89      0.91     10186
#
#    micro avg       0.87      0.87      0.87     14118
#    macro avg       0.83      0.84      0.84     14118
# weighted avg       0.87      0.87      0.87     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1']
# Test confusion matrix
# [[3211  721]
#  [1163 9023]]
# [[0.81663276 0.18336724]
#  [0.11417632 0.88582368]]
# auc 0.9112047827998415
# gini 0.822409565599683
# acc 0.8665533361665958
# f1macro 0.8393225796669272
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.73      0.82      0.77      3932
#            1       0.93      0.89      0.91     10186
#
#    micro avg       0.87      0.87      0.87     14118
#    macro avg       0.83      0.85      0.84     14118
# weighted avg       0.87      0.87      0.87     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3']
# Test confusion matrix
# [[3209  723]
#  [1156 9030]]
# [[0.81612411 0.18387589]
#  [0.1134891  0.8865109 ]]
# auc 0.9154348896886177
# gini 0.8308697793772355
# acc 0.8669074939793172
# f1macro 0.8396475890008579
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.77      3932
#            1       0.93      0.89      0.91     10186
#
#    micro avg       0.87      0.87      0.87     14118
#    macro avg       0.83      0.85      0.84     14118
# weighted avg       0.87      0.87      0.87     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2']
# Test confusion matrix
# [[3170  762]
#  [ 565 9621]]
# [[0.80620549 0.19379451]
#  [0.05546829 0.94453171]]
# auc 0.9458088206360674
# gini 0.8916176412721348
# acc 0.9060065165037541
# f1macro 0.8812030039620862
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83      3932
#            1       0.93      0.94      0.94     10186
#
#    micro avg       0.91      0.91      0.91     14118
#    macro avg       0.89      0.88      0.88     14118
# weighted avg       0.90      0.91      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4']
# Test confusion matrix
# [[3170  762]
#  [ 565 9621]]
# [[0.80620549 0.19379451]
#  [0.05546829 0.94453171]]
# auc 0.9458088206360674
# gini 0.8916176412721348
# acc 0.9060065165037541
# f1macro 0.8812030039620862
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83      3932
#            1       0.93      0.94      0.94     10186
#
#    micro avg       0.91      0.91      0.91     14118
#    macro avg       0.89      0.88      0.88     14118
# weighted avg       0.90      0.91      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4']
# Test confusion matrix
# [[3726  206]
#  [1155 9031]]
# [[0.94760936 0.05239064]
#  [0.11339093 0.88660907]]
# auc 0.9709518794771274
# gini 0.9419037589542547
# acc 0.9035982433772489
# f1macro 0.887748740544021
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.89      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1']
# Test confusion matrix
# [[3747  185]
#  [1224 8962]]
# [[0.95295015 0.04704985]
#  [0.12016493 0.87983507]]
# auc 0.9740914613818777
# gini 0.9481829227637555
# acc 0.9001983283751239
# f1macro 0.88442908642216
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.75      0.95      0.84      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.88     14118
# weighted avg       0.92      0.90      0.90     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1']
# Test confusion matrix
# [[3754  178]
#  [1229 8957]]
# [[0.95473042 0.04526958]
#  [0.1206558  0.8793442 ]]
# auc 0.9750310426474492
# gini 0.9500620852948984
# acc 0.9003399915002125
# f1macro 0.8846768949991297
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.75      0.95      0.84      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.88     14118
# weighted avg       0.92      0.90      0.90     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2']
# Test confusion matrix
# [[3760  172]
#  [1238 8948]]
# [[0.95625636 0.04374364]
#  [0.12153937 0.87846063]]
# auc 0.9753266131939816
# gini 0.9506532263879632
# acc 0.9001274968125796
# f1macro 0.8845354866499098
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.75      0.96      0.84      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.88     14118
# weighted avg       0.92      0.90      0.90     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4']
# Test confusion matrix
# [[3760  172]
#  [1238 8948]]
# [[0.95625636 0.04374364]
#  [0.12153937 0.87846063]]
# auc 0.9753446650190485
# gini 0.950689330038097
# acc 0.9001274968125796
# f1macro 0.8845354866499098
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.75      0.96      0.84      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.88     14118
# weighted avg       0.92      0.90      0.90     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4']
# Test confusion matrix
# [[3750  182]
#  [1182 9004]]
# [[0.95371312 0.04628688]
#  [0.11604163 0.88395837]]
# auc 0.9755284041347718
# gini 0.9510568082695436
# acc 0.9033857486896161
# f1macro 0.8878541156203714
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3']
# Test confusion matrix
# [[3749  183]
#  [1191 8995]]
# [[0.9534588  0.0465412 ]
#  [0.11692519 0.88307481]]
# auc 0.9755316000318791
# gini 0.9510632000637582
# acc 0.9026774330641734
# f1macro 0.8870871672289724
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0']
# Test confusion matrix
# [[3754  178]
#  [1192 8994]]
# [[0.95473042 0.04526958]
#  [0.11702337 0.88297663]]
# auc 0.9759212248315612
# gini 0.9518424496631224
# acc 0.9029607593143505
# f1macro 0.8874570956819562
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0']
# Test confusion matrix
# [[3748  184]
#  [1187 8999]]
# [[0.95320448 0.04679552]
#  [0.1165325  0.8834675 ]]
# auc 0.9759480653736733
# gini 0.9518961307473466
# acc 0.9028899277518062
# f1macro 0.8872992711406089
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1']
# Test confusion matrix
# [[3748  184]
#  [1187 8999]]
# [[0.95320448 0.04679552]
#  [0.1165325  0.8834675 ]]
# auc 0.9759476658865349
# gini 0.9518953317730698
# acc 0.9028899277518062
# f1macro 0.8872992711406089
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1']
# Test confusion matrix
# [[3750  182]
#  [1190 8996]]
# [[0.95371312 0.04628688]
#  [0.11682702 0.88317298]]
# auc 0.9761293701146468
# gini 0.9522587402292937
# acc 0.9028190961892619
# f1macro 0.8872515236085518
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.88      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1']
# Test confusion matrix
# [[3747  185]
#  [1166 9020]]
# [[0.95295015 0.04704985]
#  [0.11447084 0.88552916]]
# auc 0.9763255182996069
# gini 0.9526510365992138
# acc 0.9043065590026916
# f1macro 0.8887934204789077
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.89      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1' 'website_trigram_term_bin_2']
# Test confusion matrix
# [[3746  186]
#  [1165 9021]]
# [[0.95269583 0.04730417]
#  [0.11437267 0.88562733]]
# auc 0.9763153188936045
# gini 0.9526306377872089
# acc 0.9043065590026916
# f1macro 0.8887797404826907
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.89      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1' 'website_trigram_term_bin_2'
#  'zip_trigram_simple_bin_1']
# Test confusion matrix
# [[3746  186]
#  [1166 9020]]
# [[0.95269583 0.04730417]
#  [0.11447084 0.88552916]]
# auc 0.9762884783514924
# gini 0.9525769567029847
# acc 0.9042357274401474
# f1macro 0.8887042622172665
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.89      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1' 'website_trigram_term_bin_2'
#  'zip_trigram_simple_bin_1' 'zip_trigram_simple_bin_3']
# Test confusion matrix
# [[3746  186]
#  [1162 9024]]
# [[0.95269583 0.04730417]
#  [0.11407815 0.88592185]]
# auc 0.9763647054910906
# gini 0.9527294109821811
# acc 0.9045190536903244
# f1macro 0.88900622323584
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.89      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1' 'website_trigram_term_bin_2'
#  'zip_trigram_simple_bin_1' 'zip_trigram_simple_bin_3'
#  'website_trigram_term_bin_3']
# Test confusion matrix
# [[3746  186]
#  [1161 9025]]
# [[0.95269583 0.04730417]
#  [0.11397997 0.88602003]]
# auc 0.9764048289805547
# gini 0.9528096579611094
# acc 0.9045898852528687
# f1macro 0.8890817334862415
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.85      3932
#            1       0.98      0.89      0.93     10186
#
#    micro avg       0.90      0.90      0.90     14118
#    macro avg       0.87      0.92      0.89     14118
# weighted avg       0.92      0.90      0.91     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1' 'website_trigram_term_bin_2'
#  'zip_trigram_simple_bin_1' 'zip_trigram_simple_bin_3'
#  'website_trigram_term_bin_3' 'name_trigram_simple_bin_3']
# Test confusion matrix
# [[3713  219]
#  [ 949 9237]]
# [[0.94430315 0.05569685]
#  [0.09316709 0.90683291]]
# auc 0.9777357453501194
# gini 0.9554714907002388
# acc 0.917268734948293
# f1macro 0.9023134067222411
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86      3932
#            1       0.98      0.91      0.94     10186
#
#    micro avg       0.92      0.92      0.92     14118
#    macro avg       0.89      0.93      0.90     14118
# weighted avg       0.93      0.92      0.92     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1' 'website_trigram_term_bin_2'
#  'zip_trigram_simple_bin_1' 'zip_trigram_simple_bin_3'
#  'website_trigram_term_bin_3' 'name_trigram_simple_bin_3'
#  'street_number_levenshtein_bin_1']
# Test confusion matrix
# [[3713  219]
#  [ 953 9233]]
# [[0.94430315 0.05569685]
#  [0.09355979 0.90644021]]
# auc 0.9777870794474054
# gini 0.9555741588948108
# acc 0.9169854086981158
# f1macro 0.9020045091096509
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86      3932
#            1       0.98      0.91      0.94     10186
#
#    micro avg       0.92      0.92      0.92     14118
#    macro avg       0.89      0.93      0.90     14118
# weighted avg       0.93      0.92      0.92     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1' 'website_trigram_term_bin_2'
#  'zip_trigram_simple_bin_1' 'zip_trigram_simple_bin_3'
#  'website_trigram_term_bin_3' 'name_trigram_simple_bin_3'
#  'street_number_levenshtein_bin_1' 'website_levenshtein_simple_bin_3']
# Test confusion matrix
# [[3715  217]
#  [ 954 9232]]
# [[0.9448118  0.0551882 ]
#  [0.09365796 0.90634204]]
# auc 0.9777664434399118
# gini 0.9555328868798236
# acc 0.9170562402606601
# f1macro 0.9021073197646373
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86      3932
#            1       0.98      0.91      0.94     10186
#
#    micro avg       0.92      0.92      0.92     14118
#    macro avg       0.89      0.93      0.90     14118
# weighted avg       0.93      0.92      0.92     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1' 'website_trigram_term_bin_2'
#  'zip_trigram_simple_bin_1' 'zip_trigram_simple_bin_3'
#  'website_trigram_term_bin_3' 'name_trigram_simple_bin_3'
#  'street_number_levenshtein_bin_1' 'website_levenshtein_simple_bin_3'
#  'city_levenshtein_term_bin_4']
# Test confusion matrix
# [[3652  280]
#  [ 825 9361]]
# [[0.92878942 0.07121058]
#  [0.08099352 0.91900648]]
# auc 0.9784904015225254
# gini 0.9569808030450508
# acc 0.921731123388582
# f1macro 0.9064305457332577
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      3932
#            1       0.97      0.92      0.94     10186
#
#    micro avg       0.92      0.92      0.92     14118
#    macro avg       0.89      0.92      0.91     14118
# weighted avg       0.93      0.92      0.92     14118
# ########## ['name_trigram_term_bin_0' 'phone_trigram_bin_3'
#  'street_trigram_term_bin_0' 'name_trigram_simple_bin_0'
#  'name_trigram_simple_bin_4' 'city_trigram_simple_bin_1'
#  'phone_trigram_bin_1' 'name_trigram_term_bin_3' 'phone_equality_2'
#  'phone_trigram_bin_4' 'street_number_levenshtein_bin_4'
#  'street_number_trigram_bin_1' 'phone_equality_1'
#  'street_number_equality_2' 'street_number_trigram_bin_4'
#  'name_trigram_term_bin_4' 'street_trigram_term_bin_3'
#  'street_number_levenshtein_bin_0' 'website_trigram_term_bin_0'
#  'phone_trigram_bin_-1' 'city_levenshtein_simple_bin_1'
#  'zip_trigram_term_bin_1' 'website_trigram_term_bin_2'
#  'zip_trigram_simple_bin_1' 'zip_trigram_simple_bin_3'
#  'website_trigram_term_bin_3' 'name_trigram_simple_bin_3'
#  'street_number_levenshtein_bin_1' 'website_levenshtein_simple_bin_3'
#  'city_levenshtein_term_bin_4' 'street_trigram_term_bin_2']

# %%
feat_eval
# Out:
#                                                   col       auc       acc  \
# 0                   ['name_levenshtein_simple_bin_0']  0.631038  0.776172
# 1   ['name_levenshtein_simple_bin_0', 'name_levens...  0.792818  0.837300
# 2   ['name_levenshtein_simple_bin_0', 'name_levens...  0.851844  0.776172
# 3   ['name_levenshtein_simple_bin_0', 'name_levens...  0.868101  0.776172
# 4   ['name_levenshtein_simple_bin_0', 'name_levens...  0.868101  0.776172
# 5   ['name_levenshtein_simple_bin_0', 'name_levens...  0.877016  0.776172
# 6   ['name_levenshtein_simple_bin_0', 'name_levens...  0.882447  0.841196
# 7   ['name_levenshtein_simple_bin_0', 'name_levens...  0.886406  0.841196
# 8   ['name_levenshtein_simple_bin_0', 'name_levens...  0.886846  0.841196
# 9   ['name_levenshtein_simple_bin_0', 'name_levens...  0.886931  0.841196
# 10  ['name_levenshtein_simple_bin_0', 'name_levens...  0.886846  0.841196
# 11  ['name_levenshtein_simple_bin_0', 'name_levens...  0.888935  0.841196
# 12  ['name_levenshtein_simple_bin_0', 'name_levens...  0.890322  0.830642
# 13  ['name_levenshtein_simple_bin_0', 'name_levens...  0.891130  0.830642
# 14  ['name_levenshtein_simple_bin_0', 'name_levens...  0.891130  0.830642
# 15  ['name_levenshtein_simple_bin_0', 'name_levens...  0.893013  0.838079
# 16  ['name_levenshtein_simple_bin_0', 'name_levens...  0.895470  0.844666
# 17  ['name_levenshtein_simple_bin_0', 'name_levens...  0.896634  0.843037
# 18  ['name_levenshtein_simple_bin_0', 'name_levens...  0.896298  0.836025
# 19  ['name_levenshtein_simple_bin_0', 'name_levens...  0.896386  0.835954
# 20  ['name_levenshtein_simple_bin_0', 'name_levens...  0.906413  0.838787
# 21  ['name_levenshtein_simple_bin_0', 'name_levens...  0.906705  0.838150
# 22  ['name_levenshtein_simple_bin_0', 'name_levens...  0.908009  0.845446
# 23  ['name_levenshtein_simple_bin_0', 'name_levens...  0.908049  0.846012
# 24  ['name_levenshtein_simple_bin_0', 'name_levens...  0.910975  0.843675
# 25  ['name_levenshtein_simple_bin_0', 'name_levens...  0.910979  0.843675
# 26  ['name_levenshtein_simple_bin_0', 'name_levens...  0.910978  0.843675
# 27  ['name_levenshtein_simple_bin_0', 'name_levens...  0.911025  0.843958
# 28  ['name_levenshtein_simple_bin_0', 'name_levens...  0.911701  0.845729
# 29  ['name_levenshtein_simple_bin_0', 'name_levens...  0.911785  0.845800
#
#      f1macro                                          confusion
# 0   0.645476  ([[1193, 2739], [421, 9765]], [[0.303407934893...
# 1   0.794901  ([[2701, 1231], [1066, 9120]], [[0.68692777212...
# 2   0.755688  ([[3435, 497], [2663, 7523]], [[0.873601220752...
# 3   0.755688  ([[3435, 497], [2663, 7523]], [[0.873601220752...
# 4   0.755688  ([[3435, 497], [2663, 7523]], [[0.873601220752...
# 5   0.755688  ([[3435, 497], [2663, 7523]], [[0.873601220752...
# 6   0.811242  ([[3126, 806], [1436, 8750]], [[0.795015259409...
# 7   0.811242  ([[3126, 806], [1436, 8750]], [[0.795015259409...
# 8   0.811242  ([[3126, 806], [1436, 8750]], [[0.795015259409...
# 9   0.811242  ([[3126, 806], [1436, 8750]], [[0.795015259409...
# 10  0.811242  ([[3126, 806], [1436, 8750]], [[0.795015259409...
# 11  0.811242  ([[3126, 806], [1436, 8750]], [[0.795015259409...
# 12  0.802330  ([[3192, 740], [1651, 8535]], [[0.811800610376...
# 13  0.802330  ([[3192, 740], [1651, 8535]], [[0.811800610376...
# 14  0.802330  ([[3192, 740], [1651, 8535]], [[0.811800610376...
# 15  0.809528  ([[3183, 749], [1537, 8649]], [[0.809511698880...
# 16  0.818767  ([[3294, 638], [1555, 8631]], [[0.837741607324...
# 17  0.817197  ([[3297, 635], [1581, 8605]], [[0.838504577822...
# 18  0.810777  ([[3323, 609], [1706, 8480]], [[0.845116988809...
# 19  0.810775  ([[3326, 606], [1710, 8476]], [[0.845879959308...
# 20  0.812224  ([[3266, 666], [1610, 8576]], [[0.830620549338...
# 21  0.811703  ([[3271, 661], [1624, 8562]], [[0.831892166836...
# 22  0.818520  ([[3249, 683], [1499, 8687]], [[0.826297049847...
# 23  0.819116  ([[3250, 682], [1492, 8694]], [[0.826551373346...
# 24  0.817175  ([[3268, 664], [1543, 8643]], [[0.831129196337...
# 25  0.817175  ([[3268, 664], [1543, 8643]], [[0.831129196337...
# 26  0.817175  ([[3268, 664], [1543, 8643]], [[0.831129196337...
# 27  0.817483  ([[3269, 663], [1540, 8646]], [[0.831383519837...
# 28  0.819314  ([[3271, 661], [1517, 8669]], [[0.831892166836...
# 29  0.819409  ([[3272, 660], [1517, 8669]], [[0.832146490335...

# %% [markdown]
# # Ensembling

# %%
from sklearn.ensemble import VotingClassifier

clf_list = []
clf_list.append( ("clf_log", clf_log) )
clf_list.append( ("clf_lgb", clf_lgb) )
clf_list.append( ("clf_svc", clf_svc) )


clf_ens = VotingClassifier(clf_list, voting= "soft")  #Soft is required
print(clf_ens1)
# Out:
# VotingClassifier(estimators=[('clf_log', LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False)), ('cl...bf', max_iter=-1, probability=True, random_state=None,
#   shrinking=True, tol=0.001, verbose=False))],
#          flatten_transform=None, n_jobs=None, voting='soft', weights=None)

# %%
sk_model_eval_classification(clf_ens, 1,
                                           Xtrain, ytrain, Xtest, ytest)
# Out:
# ############# Train dataset  ####################################
# Test confusion matrix
# [[3652  389]
#  [ 440 9636]]
# [[0.9037367  0.0962633 ]
#  [0.04366812 0.95633188]]
# auc 0.9862800204218786
# gini 0.9725600408437571
# acc 0.9412764751717787
# f1macro 0.9284139318744533
# Nsample 14117
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90      4041
#            1       0.96      0.96      0.96     10076
#
#    micro avg       0.94      0.94      0.94     14117
#    macro avg       0.93      0.93      0.93     14117
# weighted avg       0.94      0.94      0.94     14117
# ############# Test dataset  #########################################
# Test confusion matrix
# [[3520  412]
#  [ 487 9699]]
# [[0.89521872 0.10478128]
#  [0.04781072 0.95218928]]
# auc 0.9838409824467349
# gini 0.9676819648934698
# acc 0.9363224252727015
# f1macro 0.9212346484656249
# Nsample 14118
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      3932
#            1       0.96      0.95      0.96     10186
#
#    micro avg       0.94      0.94      0.94     14118
#    macro avg       0.92      0.92      0.92     14118
# weighted avg       0.94      0.94      0.94     14118
# (VotingClassifier(estimators=[('clf_log', LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#            fit_intercept=True, intercept_scaling=1, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#            solver='warn', tol=0.0001, verbose=0, warm_start=False)), ('cl...bf', max_iter=-1, probability=True, random_state=None,
#    shrinking=True, tol=0.001, verbose=False))],
#           flatten_transform=None, n_jobs=None, voting='soft', weights=None),
#  {'ytest_pred': array([ 1, -1, -1, ...,  1,  1,  1], dtype=int64)})

# %% [markdown]
# # Saving models

# %%
colname_list  =  [  "colnum", "colnum_bin",  
                  "colcat", "colcat_onehot" ] 
colname_list  = { x: globals()[x]   for x in colname_list }


folder_model = folder + "/models/model_01/" 





var_list = [
     "pipe_preprocess_colnum",  ## Pre-processors
     "pipe_preprocess_colcat",  ##
     
     ##### Data
     "df",
     "dfcat_hot",
     "dfnum_hot",
     "dfX",
     "colname_list",
      
     ##### Model
     "clf_log",
     "clf_lgb",
     "clf_svc"
        
     ]

util.save_all(var_list , folder_model, globals_main= globals() )
# Out:
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//pipe_preprocess_colnum.pkl
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//pipe_preprocess_colcat.pkl
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//df.pkl
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//dfcat_hot.pkl
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//dfnum_hot.pkl
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//dfX.pkl
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//colname_list.pkl
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//clf_log.pkl
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//clf_lgb.pkl
# D:\_devs\Python01\gitdev\dsa\dsa//models/model_01//clf_svc.pkl

# %%
util.save(clf_log , folder_model + "/clf_predict.pkl")
# Out:
# 'D:\\_devs\\Python01\\gitdev\\da\\da//models/model_01//clf_predict.pkl'

# %%
### Validate pkl data
for x in var_list :
  _ = util.load(  "{a}/{b}.pkl".format(a=folder_model, b=x  ))
  print(x)
# Out:
# pipe_preprocess_colnum
# pipe_preprocess_colcat
# df
# dfcat_hot
# dfnum_hot
# dfX
# colname_list
# clf_log
# clf_lgb
# clf_svc

# %% [markdown]
# # Predict values

# %%
# Out:
# pipe_preprocess_colnum
# pipe_preprocess_colcat
# df
# dfcat_hot
# dfnum_hot
# dfX
# colname_list
# clf_log
# clf_lgb
# clf_svc

# %%
dft = pd.read_csv(folder + '/data/address_matching_data.csv')

# %%
##### Pre-Process Giobally
coly = "is_match"
colid = "id"


dft = dft.set_index( colid)
dft = dft.replace("?",  np.nan)

# %%
dft.head(3)
# Out:
#            name_levenshtein_simple  name_trigram_simple  \
# id
# 1204#1207                 0.666667             0.666667
# 1272#1279                 0.666667             0.666667
# 6258#6259                 1.000000             1.000000
#
#            name_levenshtein_term  name_trigram_term city_levenshtein_simple  \
# id
# 1204#1207               0.400000           0.526316                     NaN
# 1272#1279               0.411765           0.444444                     NaN
# 6258#6259               1.000000           1.000000                       1
#
#           city_trigram_simple city_levenshtein_term city_trigram_term  \
# id
# 1204#1207                 NaN                   NaN               NaN
# 1272#1279                 NaN                   NaN               NaN
# 6258#6259                   1                     1                 1
#
#           zip_levenshtein_simple zip_trigram_simple  ... phone_levenshtein  \
# id                                                   ...
# 1204#1207                    NaN                NaN  ...               NaN
# 1272#1279                    NaN                NaN  ...               NaN
# 6258#6259                      1                  1  ...               1.0
#
#           phone_trigram fax_levenshtein fax_trigram street_number_levenshtein  \
# id
# 1204#1207           NaN             NaN         NaN                       1.0
# 1272#1279           NaN             NaN         NaN                       1.0
# 6258#6259           1.0             NaN         NaN                       1.0
#
#           street_number_trigram phone_equality fax_equality  \
# id
# 1204#1207                   1.0              m            m
# 1272#1279                   1.0              m            m
# 6258#6259                   1.0              s            m
#
#           street_number_equality is_match
# id
# 1204#1207                      s        1
# 1272#1279                      s        1
# 6258#6259                      s        1
#
# [3 rows x 30 columns]

# %%
#### Pre-processing  cat :  ##################################
dft_cat = util_feature.pd_pipeline_apply( dft[colcat].iloc[:,:], 
                                            pipe_preprocess_colcat )  



dft_cat.head(4)
# Out:
# ############## Pipeline  0 Start (28235, 3) pd_col_fillna
# phone_equality 0 replaceBY -1
# fax_equality 0 replaceBY -1
# street_number_equality 0 replaceBY -1
# ############## Pipeline   0 Finished (28235, 3)
# ############## Pipeline  1 Start (28235, 3) pd_col_to_onehot
# phone_equality 3 (28235, 3)
# fax_equality 3 (28235, 5)
# street_number_equality 3 (28235, 7)
# phone_equality_0 added
# phone_equality_1 added
# phone_equality_2 added
# fax_equality_0 added
# fax_equality_1 added
# fax_equality_2 added
# street_number_equality_0 added
# street_number_equality_1 added
# street_number_equality_2 added
# ############## Pipeline   1 Finished (28235, 9)
#              phone_equality_0  phone_equality_1  phone_equality_2  \
# id
# 1204#1207                   0                 0                 0
# 1272#1279                   0                 0                 0
# 6258#6259                   0                 0                 0
# 16076#16077                 0                 0                 0
#
#              fax_equality_0  fax_equality_1  fax_equality_2  \
# id
# 1204#1207                 0               0               0
# 1272#1279                 0               0               0
# 6258#6259                 0               0               0
# 16076#16077               0               0               0
#
#              street_number_equality_0  street_number_equality_1  \
# id
# 1204#1207                           0                         0
# 1272#1279                           0                         0
# 6258#6259                           0                         0
# 16076#16077                         0                         0
#
#              street_number_equality_2
# id
# 1204#1207                           0
# 1272#1279                           0
# 6258#6259                           0
# 16076#16077                         0

# %%
#### Pre-processing  cat : #################################################
dft_num = util_feature.pd_pipeline_apply( dft[colnum].iloc[:,:], 
                                            pipe_preprocess_colnum )  

dft_num.head(4)
# Out:
# ############## Pipeline  0 Start (28235, 26) pd_col_to_num
# ############## Pipeline   0 Finished (28235, 26)
# ############## Pipeline  1 Start (28235, 26) pd_colnum_tocat
# name_levenshtein_simple
#                             name_levenshtein_simple
#                                                 min   size      mean       max
# name_levenshtein_simple_bin
# 0                                               0.0   3244  0.133234  0.199916
# 1                                               0.2   4352  0.284679  0.399802
# 2                                               0.4   4713  0.495519  0.599206
# 3                                               0.6   4992  0.679888  0.797778
# 4                                               0.8  10934  0.945298  1.000000
# name_trigram_simple
#                         name_trigram_simple
#                                         min   size      mean       max
# name_trigram_simple_bin
# 0                                       0.0   6913  0.034203  0.199356
# 1                                       0.2   2304  0.303970  0.398810
# 2                                       0.4   4347  0.493030  0.598639
# 3                                       0.6   4046  0.681848  0.793269
# 4                                       0.8  10625  0.947331  1.000000
# name_levenshtein_term
#                           name_levenshtein_term
#                                             min  size      mean       max
# name_levenshtein_term_bin
# 0                                           0.0  4796  0.128121  0.196429
# 1                                           0.2  7258  0.283608  0.397059
# 2                                           0.4  4867  0.494029  0.595745
# 3                                           0.6  3306  0.688375  0.793103
# 4                                           0.8  8008  0.975184  1.000000
# name_trigram_term
#                       name_trigram_term
#                                     min  size      mean       max
# name_trigram_term_bin
# 0                                   0.0  7820  0.044257  0.196970
# 1                                   0.2  4141  0.305079  0.395833
# 2                                   0.4  4378  0.490261  0.596774
# 3                                   0.6  3371  0.688602  0.795455
# 4                                   0.8  8525  0.974722  1.000000
# city_levenshtein_simple
#                             city_levenshtein_simple
#                                                 min   size      mean       max
# city_levenshtein_simple_bin
# -1                                              NaN  18290       NaN       NaN
#  0                                              0.0    540  0.095143  0.197917
#  1                                              0.2    287  0.274496  0.397959
#  2                                              0.4    311  0.543002  0.583333
#  3                                              0.6    873  0.665268  0.792857
#  4                                              0.8   7934  0.995194  1.000000
# city_trigram_simple
#                         city_trigram_simple
#                                         min   size      mean       max
# city_trigram_simple_bin
# -1                                      NaN  18290       NaN       NaN
#  0                                 0.000000    857  0.018133  0.190476
#  1                                 0.200000    414  0.336874  0.375000
#  2                                 0.400000    141  0.485682  0.583333
#  3                                 0.602778    794  0.670119  0.791667
#  4                                 0.800000   7739  0.998901  1.000000
# city_levenshtein_term
#                           city_levenshtein_term
#                                             min   size      mean       max
# city_levenshtein_term_bin
# -1                                          NaN  18290       NaN       NaN
#  0                                          0.0    645  0.097827  0.192308
#  1                                          0.2    249  0.266688  0.384615
#  2                                          0.4    975  0.499026  0.583333
#  3                                          0.6    172  0.669885  0.785714
#  4                                          0.8   7904  0.999129  1.000000
# city_trigram_term
#                       city_trigram_term
#                                     min   size      mean       max
# city_trigram_term_bin
# -1                                  NaN  18290       NaN       NaN
#  0                                  0.0    859  0.017975  0.193548
#  1                                  0.2    295  0.351800  0.391304
#  2                                  0.4    743  0.514457  0.588235
#  3                                  0.6    172  0.673442  0.782609
#  4                                  0.8   7876  0.999780  1.000000
# zip_levenshtein_simple
#                            zip_levenshtein_simple
#                                               min   size      mean       max
# zip_levenshtein_simple_bin
# -1                                            NaN  20539       NaN       NaN
#  0                                            0.0    308  0.003788  0.166667
#  1                                            0.2    261  0.222763  0.333333
#  2                                            0.4    104  0.456685  0.533333
#  3                                            0.6    271  0.647233  0.750000
#  4                                            0.8   6752  0.977009  1.000000
# zip_trigram_simple
#                        zip_trigram_simple
#                                       min   size      mean       max
# zip_trigram_simple_bin
# -1                                    NaN  20539       NaN       NaN
#  0                               0.000000    617  0.013905  0.181818
#  1                               0.200000    673  0.316570  0.375000
#  2                               0.428571    309  0.528895  0.571429
#  3                               0.600000    126  0.664021  0.666667
#  4                               1.000000   5971  1.000000  1.000000
# zip_levenshtein_term
#                          zip_levenshtein_term
#                                           min   size      mean       max
# zip_levenshtein_term_bin
# -1                                        NaN  20539       NaN       NaN
#  0                                        0.0    308  0.003711  0.142857
#  1                                        0.2    295  0.236913  0.375000
#  2                                        0.4    151  0.453307  0.571429
#  3                                        0.6    187  0.653425  0.750000
#  4                                        0.8   6755  0.977079  1.000000
# zip_trigram_term
#                      zip_trigram_term
#                                   min   size      mean       max
# zip_trigram_term_bin
# -1                                NaN  20539       NaN       NaN
#  0                                0.0    617  0.013858  0.181818
#  1                                0.2    678  0.316307  0.375000
#  2                                0.4    396  0.504769  0.571429
#  3                                0.6     34  0.604167  0.666667
#  4                                1.0   5971  1.000000  1.000000
# street_levenshtein_simple
#                               street_levenshtein_simple                   \
#                                                     min   size      mean
# street_levenshtein_simple_bin
# -1                                                  NaN  19997       NaN
#  0                                                  0.0    615  0.139081
#  1                                                  0.2   1548  0.298834
#  2                                                  0.4    874  0.488772
#  3                                                  0.6   1015  0.705490
#  4                                                  0.8   4186  0.958354
#
#
#                                     max
# street_levenshtein_simple_bin
# -1                                  NaN
#  0                             0.198810
#  1                             0.399471
#  2                             0.596429
#  3                             0.798611
#  4                             1.000000
# street_trigram_simple
#                           street_trigram_simple
#                                             min   size      mean       max
# street_trigram_simple_bin
# -1                                          NaN  19997       NaN       NaN
#  0                                          0.0   1669  0.038069  0.198485
#  1                                          0.2   1020  0.281841  0.399669
#  2                                          0.4    575  0.499309  0.596875
#  3                                          0.6   1026  0.706532  0.793651
#  4                                          0.8   3948  0.958941  1.000000
# street_levenshtein_term
#                             street_levenshtein_term
#                                                 min   size      mean       max
# street_levenshtein_term_bin
# -1                                              NaN  19997       NaN       NaN
#  0                                              0.0    713  0.142500  0.196721
#  1                                              0.2   1847  0.285521  0.394737
#  2                                              0.4    882  0.485934  0.595238
#  3                                              0.6    666  0.703717  0.794118
#  4                                              0.8   4130  0.965269  1.000000
# street_trigram_term
#                         street_trigram_term
#                                         min   size      mean       max
# street_trigram_term_bin
# -1                                      NaN  19997       NaN       NaN
#  0                                      0.0   2532  0.068234  0.195652
#  1                                      0.2    522  0.287067  0.396825
#  2                                      0.4    569  0.512796  0.596491
#  3                                      0.6    854  0.712352  0.796610
#  4                                      0.8   3761  0.970748  1.000000
# website_levenshtein_simple
#                                website_levenshtein_simple                   \
#                                                       min   size      mean
# website_levenshtein_simple_bin
# -1                                               1.000000  27322  1.000000
#  0                                               0.175000     43  0.290345
#  1                                               0.341737    187  0.450517
#  2                                               0.505000    281  0.564912
#  3                                               0.674603    251  0.756285
#  4                                               0.841270    151  0.878878
#
#
#                                      max
# website_levenshtein_simple_bin
# -1                              1.000000
#  0                              0.335924
#  1                              0.504762
#  2                              0.668750
#  3                              0.833333
#  4                              0.979167
# website_trigram_simple
#                            website_trigram_simple
#                                               min   size      mean       max
# website_trigram_simple_bin
# -1                                            NaN  26416       NaN       NaN
#  0                                       0.028219     45  0.127279  0.212903
#  1                                       0.223214    163  0.346492  0.414286
#  2                                       0.420000    292  0.486172  0.606061
#  3                                       0.613889    254  0.722279  0.800000
#  4                                       0.810458   1065  0.978935  1.000000
# website_levenshtein_term
#                              website_levenshtein_term                   \
#                                                   min   size      mean
# website_levenshtein_term_bin
# -1                                                NaN  26416       NaN
#  0                                           0.061856     57  0.195947
#  1                                           0.250000    352  0.339616
#  2                                           0.440000    217  0.538076
#  3                                           0.625000    159  0.715684
#  4                                           0.821429   1034  0.986927
#
#
#                                    max
# website_levenshtein_term_bin
# -1                                 NaN
#  0                            0.247191
#  1                            0.434783
#  2                            0.621622
#  3                            0.809524
#  4                            1.000000
# website_trigram_term
#                          website_trigram_term
#                                           min   size      mean       max
# website_trigram_term_bin
# -1                                        NaN  26416       NaN       NaN
#  0                                   0.025316    236  0.166508  0.219512
#  1                                   0.220339    283  0.302246  0.413793
#  2                                   0.424242    154  0.518842  0.609756
#  3                                   0.617647    137  0.718212  0.800000
#  4                                   0.806452   1009  0.984178  1.000000
# phone_levenshtein
#                       phone_levenshtein
#                                     min   size      mean       max
# phone_levenshtein_bin
# -1                             1.000000  24234  1.000000  1.000000
#  0                             0.100000    609  0.205098  0.272727
#  1                             0.300000   1033  0.398655  0.454545
#  2                             0.500000   1240  0.571395  0.636364
#  3                             0.666667    776  0.766481  0.818182
#  4                             0.833333    343  0.902960  0.916667
# phone_trigram
#                   phone_trigram
#                             min   size      mean       max
# phone_trigram_bin
# -1                          NaN  16371       NaN       NaN
#  0                          0.0   1042  0.091661  0.187500
#  1                          0.2   1731  0.274957  0.375000
#  2                          0.4    618  0.459597  0.571429
#  3                          0.6    610  0.635614  0.733333
#  4                          1.0   7863  1.000000  1.000000
# fax_levenshtein
#                     fax_levenshtein
#                                 min   size      mean       max
# fax_levenshtein_bin
# -1                              1.0  27891  1.000000  1.000000
#  0                              0.1     34  0.175401  0.272727
#  1                              0.3    115  0.384269  0.454545
#  2                              0.5    130  0.553706  0.636364
#  3                              0.7     49  0.725046  0.818182
#  4                              0.9     16  0.907386  0.909091
# fax_trigram
#                 fax_trigram
#                         min   size      mean       max
# fax_trigram_bin
# -1                      NaN  27505       NaN       NaN
#  0                 0.047619    182  0.150437  0.235294
#  1                 0.263158    120  0.325706  0.411765
#  2                 0.428571     32  0.506250  0.600000
#  3                 0.692308     10  0.709890  0.714286
#  4                 1.000000    386  1.000000  1.000000
# street_number_levenshtein
#                               street_number_levenshtein                   \
#                                                     min   size      mean
# street_number_levenshtein_bin
# -1                                                  NaN   9852       NaN
#  0                                                  0.0    285  0.000000
#  1                                                  0.2    144  0.293634
#  2                                                  0.4   2382  0.482608
#  3                                                  0.6   1417  0.702021
#  4                                                  0.8  14155  0.998723
#
#
#                                     max
# street_number_levenshtein_bin
# -1                                  NaN
#  0                             0.000000
#  1                             0.333333
#  2                             0.571429
#  3                             0.750000
#  4                             1.000000
# street_number_trigram
#                           street_number_trigram
#                                             min   size      mean       max
# street_number_trigram_bin
# -1                                          NaN   9852       NaN       NaN
#  0                                          0.0    551  0.073064  0.181818
#  1                                          0.2   3084  0.270634  0.375000
#  2                                          0.4    684  0.447116  0.571429
#  4                                          1.0  14064  1.000000  1.000000
# ############## Pipeline   1 Finished (28235, 26)
# ############## Pipeline  2 Start (28235, 26) pd_col_to_onehot
# name_levenshtein_simple_bin 5 (28235, 26)
# name_trigram_simple_bin 5 (28235, 30)
# name_levenshtein_term_bin 5 (28235, 34)
# name_trigram_term_bin 5 (28235, 38)
# city_levenshtein_simple_bin 6 (28235, 42)
# city_trigram_simple_bin 6 (28235, 47)
# city_levenshtein_term_bin 6 (28235, 52)
# city_trigram_term_bin 6 (28235, 57)
# zip_levenshtein_simple_bin 6 (28235, 62)
# zip_trigram_simple_bin 6 (28235, 67)
# zip_levenshtein_term_bin 6 (28235, 72)
# zip_trigram_term_bin 6 (28235, 77)
# street_levenshtein_simple_bin 6 (28235, 82)
# street_trigram_simple_bin 6 (28235, 87)
# street_levenshtein_term_bin 6 (28235, 92)
# street_trigram_term_bin 6 (28235, 97)
# website_levenshtein_simple_bin 6 (28235, 102)
# website_trigram_simple_bin 6 (28235, 107)
# website_levenshtein_term_bin 6 (28235, 112)
# website_trigram_term_bin 6 (28235, 117)
# phone_levenshtein_bin 6 (28235, 122)
# phone_trigram_bin 6 (28235, 127)
# fax_levenshtein_bin 6 (28235, 132)
# fax_trigram_bin 6 (28235, 137)
# street_number_levenshtein_bin 6 (28235, 142)
# street_number_trigram_bin 5 (28235, 147)
# ############## Pipeline   2 Finished (28235, 151)
#              name_levenshtein_simple_bin_0  name_levenshtein_simple_bin_1  \
# id
# 1204#1207                                0                              0
# 1272#1279                                0                              0
# 6258#6259                                0                              0
# 16076#16077                              0                              0
#
#              name_levenshtein_simple_bin_2  name_levenshtein_simple_bin_3  \
# id
# 1204#1207                                0                              1
# 1272#1279                                0                              1
# 6258#6259                                0                              0
# 16076#16077                              1                              0
#
#              name_levenshtein_simple_bin_4  name_trigram_simple_bin_0  \
# id
# 1204#1207                                0                          0
# 1272#1279                                0                          0
# 6258#6259                                1                          0
# 16076#16077                              0                          0
#
#              name_trigram_simple_bin_1  name_trigram_simple_bin_2  \
# id
# 1204#1207                            0                          0
# 1272#1279                            0                          0
# 6258#6259                            0                          0
# 16076#16077                          1                          0
#
#              name_trigram_simple_bin_3  name_trigram_simple_bin_4  ...  \
# id                                                                 ...
# 1204#1207                            1                          0  ...
# 1272#1279                            1                          0  ...
# 6258#6259                            0                          1  ...
# 16076#16077                          0                          0  ...
#
#              street_number_levenshtein_bin_0  street_number_levenshtein_bin_1  \
# id
# 1204#1207                                  0                                0
# 1272#1279                                  0                                0
# 6258#6259                                  0                                0
# 16076#16077                                1                                0
#
#              street_number_levenshtein_bin_2  street_number_levenshtein_bin_3  \
# id
# 1204#1207                                  0                                0
# 1272#1279                                  0                                0
# 6258#6259                                  0                                0
# 16076#16077                                0                                0
#
#              street_number_levenshtein_bin_4  street_number_trigram_bin_-1  \
# id
# 1204#1207                                  1                             0
# 1272#1279                                  1                             0
# 6258#6259                                  1                             0
# 16076#16077                                0                             0
#
#              street_number_trigram_bin_0  street_number_trigram_bin_1  \
# id
# 1204#1207                              0                            0
# 1272#1279                              0                            0
# 6258#6259                              0                            0
# 16076#16077                            1                            0
#
#              street_number_trigram_bin_2  street_number_trigram_bin_4
# id
# 1204#1207                              0                            1
# 1272#1279                              0                            1
# 6258#6259                              0                            1
# 16076#16077                            0                            0
#
# [4 rows x 151 columns]

# %%
df_final = pd.concat(( dft_cat, dft_num  ), axis=1)
col_final = list( df_final.columns )

df_final.head(5)
# Out:
#              phone_equality_0  phone_equality_1  phone_equality_2  \
# id
# 1204#1207                   0                 0                 0
# 1272#1279                   0                 0                 0
# 6258#6259                   0                 0                 0
# 16076#16077                 0                 0                 0
# 2666#2671                   0                 0                 0
#
#              fax_equality_0  fax_equality_1  fax_equality_2  \
# id
# 1204#1207                 0               0               0
# 1272#1279                 0               0               0
# 6258#6259                 0               0               0
# 16076#16077               0               0               0
# 2666#2671                 0               0               0
#
#              street_number_equality_0  street_number_equality_1  \
# id
# 1204#1207                           0                         0
# 1272#1279                           0                         0
# 6258#6259                           0                         0
# 16076#16077                         0                         0
# 2666#2671                           0                         0
#
#              street_number_equality_2  name_levenshtein_simple_bin_0  ...  \
# id                                                                    ...
# 1204#1207                           0                              0  ...
# 1272#1279                           0                              0  ...
# 6258#6259                           0                              0  ...
# 16076#16077                         0                              0  ...
# 2666#2671                           0                              0  ...
#
#              street_number_levenshtein_bin_0  street_number_levenshtein_bin_1  \
# id
# 1204#1207                                  0                                0
# 1272#1279                                  0                                0
# 6258#6259                                  0                                0
# 16076#16077                                1                                0
# 2666#2671                                  0                                0
#
#              street_number_levenshtein_bin_2  street_number_levenshtein_bin_3  \
# id
# 1204#1207                                  0                                0
# 1272#1279                                  0                                0
# 6258#6259                                  0                                0
# 16076#16077                                0                                0
# 2666#2671                                  0                                0
#
#              street_number_levenshtein_bin_4  street_number_trigram_bin_-1  \
# id
# 1204#1207                                  1                             0
# 1272#1279                                  1                             0
# 6258#6259                                  1                             0
# 16076#16077                                0                             0
# 2666#2671                                  1                             0
#
#              street_number_trigram_bin_0  street_number_trigram_bin_1  \
# id
# 1204#1207                              0                            0
# 1272#1279                              0                            0
# 6258#6259                              0                            0
# 16076#16077                            1                            0
# 2666#2671                              0                            0
#
#              street_number_trigram_bin_2  street_number_trigram_bin_4
# id
# 1204#1207                              0                            1
# 1272#1279                              0                            1
# 6258#6259                              0                            1
# 16076#16077                            0                            0
# 2666#2671                              0                            1
#
# [5 rows x 160 columns]

# %%
#### Train 
coly = "is_match"
dft[coly] = clf_log.predict( df_final.iloc[:,:])

dft.sample(frac=0.2).head(20)
# Out:
#              name_levenshtein_simple  name_trigram_simple  \
# id
# 1042#1037                   1.000000             1.000000
# 9074#9076                   0.500000             0.500000
# 2138#2139                   1.000000             1.000000
# 1265#1274                   0.490476             0.315629
# 7308#7309                   0.604167             0.456667
# 3930#3934                   0.126984             0.000000
# 1527#1528                   0.857143             0.857143
# 1283#1284                   0.666667             0.666667
# 883#884                     0.494444             0.366667
# 10424#10425                 0.120370             0.000000
# 15361#15362                 0.457143             0.400000
# 8186#8191                   0.242424             0.000000
# 6246#6249                   0.166667             0.000000
# 1913#1918                   0.800000             0.800000
# 5557#5558                   0.800000             0.800000
# 2481#2500                   0.666667             0.666667
# 13819#13820                 0.110714             0.000000
# 2473#2463                   1.000000             1.000000
# 2878#2880                   0.320282             0.137037
# 6563#6564                   1.000000             1.000000
#
#              name_levenshtein_term  name_trigram_term city_levenshtein_simple  \
# id
# 1042#1037                 1.000000           1.000000                     NaN
# 9074#9076                 0.235294           0.434783                       1
# 2138#2139                 1.000000           1.000000                       1
# 1265#1274                 0.363636           0.238095                       1
# 7308#7309                 0.600000           0.317073                       1
# 3930#3934                 0.153846           0.000000                       1
# 1527#1528                 0.840000           0.880000                     NaN
# 1283#1284                 0.437500           0.470588                     NaN
# 883#884                   0.590909           0.343750                     NaN
# 10424#10425               0.166667           0.000000                0.162338
# 15361#15362               0.210526           0.391304                       1
# 8186#8191                 0.218750           0.000000                     NaN
# 6246#6249                 0.250000           0.000000                       1
# 1913#1918                 0.666667           0.684211                     NaN
# 5557#5558                 0.500000           0.526316                     NaN
# 2481#2500                 0.500000           0.545455                     NaN
# 13819#13820               0.050000           0.000000                       1
# 2473#2463                 1.000000           1.000000                     NaN
# 2878#2880                 0.232558           0.105263                       1
# 6563#6564                 0.368421           1.000000                       1
#
#             city_trigram_simple city_levenshtein_term city_trigram_term  \
# id
# 1042#1037                   NaN                   NaN               NaN
# 9074#9076                     1                     1                 1
# 2138#2139                     1                     1                 1
# 1265#1274                     1                     1                 1
# 7308#7309                     1                     1                 1
# 3930#3934                     1                     1                 1
# 1527#1528                   NaN                   NaN               NaN
# 1283#1284                   NaN                   NaN               NaN
# 883#884                     NaN                   NaN               NaN
# 10424#10425                   0              0.210526                 0
# 15361#15362                   1                     1                 1
# 8186#8191                   NaN                   NaN               NaN
# 6246#6249                     1                     1                 1
# 1913#1918                   NaN                   NaN               NaN
# 5557#5558                   NaN                   NaN               NaN
# 2481#2500                   NaN                   NaN               NaN
# 13819#13820                   1                     1                 1
# 2473#2463                   NaN                   NaN               NaN
# 2878#2880                     1                     1                 1
# 6563#6564                     1                     1                 1
#
#             zip_levenshtein_simple zip_trigram_simple  ... phone_levenshtein  \
# id                                                     ...
# 1042#1037                      NaN                NaN  ...               NaN
# 9074#9076                        1                  1  ...              0.25
# 2138#2139                        1                  1  ...               NaN
# 1265#1274                        1                  1  ...    0.909090909091
# 7308#7309                      0.6           0.222222  ...               1.0
# 3930#3934                        1                  1  ...    0.272727272727
# 1527#1528                      NaN                NaN  ...               NaN
# 1283#1284                      NaN                NaN  ...               1.0
# 883#884                        NaN                NaN  ...               NaN
# 10424#10425                      0                  0  ...               NaN
# 15361#15362                    NaN                NaN  ...               NaN
# 8186#8191                      NaN                NaN  ...               NaN
# 6246#6249                      NaN                NaN  ...               1.0
# 1913#1918                      NaN                NaN  ...               NaN
# 5557#5558                      NaN                NaN  ...               NaN
# 2481#2500                      NaN                NaN  ...               NaN
# 13819#13820                      1                  1  ...               NaN
# 2473#2463                      NaN                NaN  ...               NaN
# 2878#2880                        1                  1  ...               1.0
# 6563#6564                      NaN                NaN  ...               1.0
#
#                phone_trigram fax_levenshtein fax_trigram  \
# id
# 1042#1037                NaN             NaN         NaN
# 9074#9076    0.0833333358169             NaN         NaN
# 2138#2139                NaN             NaN         NaN
# 1265#1274     0.600000023842             NaN         NaN
# 7308#7309                1.0             NaN         NaN
# 3930#3934    0.0909090936184             NaN         NaN
# 1527#1528                NaN             NaN         NaN
# 1283#1284                1.0             1.0         1.0
# 883#884                  NaN             NaN         NaN
# 10424#10425              NaN             NaN         NaN
# 15361#15362              NaN             NaN         NaN
# 8186#8191                NaN             NaN         NaN
# 6246#6249                1.0             NaN         NaN
# 1913#1918                NaN             NaN         NaN
# 5557#5558                NaN             NaN         NaN
# 2481#2500                NaN             NaN         NaN
# 13819#13820              NaN             NaN         NaN
# 2473#2463                NaN             NaN         NaN
# 2878#2880                1.0             NaN         NaN
# 6563#6564                1.0             NaN         NaN
#
#             street_number_levenshtein street_number_trigram phone_equality  \
# id
# 1042#1037                         NaN                   NaN              m
# 9074#9076                         1.0                   1.0              n
# 2138#2139                         1.0                   1.0              m
# 1265#1274                         1.0                   1.0              n
# 7308#7309                         NaN                   NaN              s
# 3930#3934                         0.5                  0.25              n
# 1527#1528                         0.8                   0.5              m
# 1283#1284                         1.0                   1.0              s
# 883#884                           1.0                   1.0              m
# 10424#10425                       NaN                   NaN              m
# 15361#15362                       NaN                   NaN              m
# 8186#8191              0.428571428571        0.181818187237              m
# 6246#6249                         1.0                   1.0              s
# 1913#1918                         1.0                   1.0              m
# 5557#5558                         0.5        0.285714298487              m
# 2481#2500                         NaN                   NaN              m
# 13819#13820                       1.0                   1.0              m
# 2473#2463                         1.0                   1.0              m
# 2878#2880                         NaN                   NaN              s
# 6563#6564              0.285714285714        0.181818187237              s
#
#             fax_equality street_number_equality is_match
# id
# 1042#1037              m                      n        1
# 9074#9076              m                      s        1
# 2138#2139              m                      s        1
# 1265#1274              m                      s       -1
# 7308#7309              m                      n       -1
# 3930#3934              m                      n       -1
# 1527#1528              m                      n        1
# 1283#1284              s                      s        1
# 883#884                m                      s        1
# 10424#10425            m                      m        1
# 15361#15362            m                      n        1
# 8186#8191              m                      n        1
# 6246#6249              m                      s        1
# 1913#1918              m                      s        1
# 5557#5558              m                      n        1
# 2481#2500              m                      n        1
# 13819#13820            m                      s        1
# 2473#2463              m                      s        1
# 2878#2880              m                      n       -1
# 6563#6564              m                      n        1
#
# [20 rows x 30 columns]

# %%
dft = dft.reset_index()

dft[[ "id", "is_match"  ]].to_csv("adress_pred.csv" , index=False, mode="w")

# %%
# Out:
# 69
