# %%
#!pip install arrow

# %%
# %matplotlib inline
import os
import pandas as pd, numpy as np, sklearn as sk
from sklearn.preprocessing import Imputer
from sklearn.model_selection import train_test_split, cross_val_score

import warnings
warnings.filterwarnings("ignore")
print( os.getcwd() )
# Out:
# /content

# %%
import util_plot 
import util_feature 
#import util_other 
import util_model 
import util_date
import util_csv
print(util_plot)

from util_plot import *
from util_model import *
from util_import import *
# Out:
# <module 'util_plot' from '/content/util_plot.py'>

# %%
#os.chdir("da")

# %%
file_path = 'data/shopping_time/'
#file_path = ""

# %%
# Unzip all the docs as csv obviously

order_items = file_path+'order_items.zip'
train_trips = file_path+'train_trips.zip'
test_trips = file_path+'test_trips.zip'
print(order_items)
# Out:
# order_items.zip

# %%
df_order_items = pd.read_csv(order_items, delimiter=',')
df_train_trips = pd.read_csv(train_trips, delimiter=',')
df_list_test_trips = pd.read_csv(test_trips, delimiter=',')
#df_list_test_trips = util_feature.col_remove()
list_dataframes = [df_order_items, df_train_trips, df_list_test_trips]

df_train = pd.merge(df_order_items, df_train_trips, on='trip_id')
df_test = pd.merge(df_order_items, df_list_test_trips, on='trip_id')

# %%
df_order_items.head(3)
# Out:
#    trip_id  item_id department_name  quantity
# 0  3119513   368671         Produce      10.0
# 1  3120462   368671         Produce      10.0
# 2  3120473   368671         Produce      10.0

# %%
####  USE THIS
colnum = [ 'quantity']
colcat = ['department_name','fulfillment_model']
coldate = ['shopping_started_at','shopping_ended_at' ]
colid = ['trip_id', 'item_id', 'shopper_id','store_id']
coltext =  None

# %%
df_train  = util_feature.pd_col_to_onehot(df = df_train, colname = colcat)
df_test  = util_feature.pd_col_to_onehot(df = df_test, colname = colcat)
# Out:
# department_name 83 (1859920, 9)
# fulfillment_model 2 (1859920, 91)
# department_name 79 (180366, 8)
# fulfillment_model 2 (180366, 86)

# %%
df_frames = [df_train, df_test]

df_full_date = pd.concat(df_frames,sort=False, join='inner')

df_full_date.head()
# Out:
#    trip_id  ...  department_name_Vitamins & Supplements
# 0  3119513  ...                                       0
# 1  3119513  ...                                       0
# 2  3119513  ...                                       0
# 3  3119513  ...                                       0
# 4  3119513  ...                                       0
#
# [5 rows x 83 columns]

# %%
df_full_date_copy = df_full_date.copy()
colcat_1hot_ =   util_feature.pd_col_remove(df_full_date_copy,colid)
colcat_1hot_ =   util_feature.pd_col_remove(colcat_1hot_,colcat)
colcat_1hot_ =   util_feature.pd_col_remove(colcat_1hot_,colnum)
colcat_1hot_ =   util_feature.pd_col_remove(colcat_1hot_,coldate)
colcat_1hot=colcat_1hot_.columns
df_full_date = df_full_date.fillna(0)

# %%
df_full_date = util_feature.pd_col_remove(df_full_date,colid)

# %%
df_full_date = util_feature.pd_col_normalize(df_full_date, 
                                             colnum, colproba= colnum)
# Out:
# quantity -1.0498221244986774 6.216805681965679
# quantity

# %%
util_feature.pd_col_fillna(df_full_date, colcat_1hot,0)
# Out:
# department_name_25% OFF Supplements 8/14-8/16 0 replaceBY 0
# department_name_4th of July 0 replaceBY 0
# department_name_Academy Awards 0 replaceBY 0
# department_name_Alcohol 0 replaceBY 0
# department_name_All It Takes to Bake! 0 replaceBY 0
# department_name_Aquatics 0 replaceBY 0
# department_name_BBQ Favorites 0 replaceBY 0
# department_name_Babies 0 replaceBY 0
# department_name_Bakery 0 replaceBY 0
# department_name_Beverages 0 replaceBY 0
# department_name_Bi-Rite Creamery 0 replaceBY 0
# department_name_Bi-Rite's Winter Favorites! 0 replaceBY 0
# department_name_Breakfast 0 replaceBY 0
# department_name_Bulk 0 replaceBY 0
# department_name_Burning Man Essentials 0 replaceBY 0
# department_name_Business Items 0 replaceBY 0
# department_name_Buyers' Picks 0 replaceBY 0
# department_name_Canned Goods 0 replaceBY 0
# department_name_Cat 0 replaceBY 0
# department_name_Cheese 0 replaceBY 0
# department_name_Christmas & NYE Menu 0 replaceBY 0
# department_name_Dairy & Eggs 0 replaceBY 0
# department_name_Deli 0 replaceBY 0
# department_name_Dog 0 replaceBY 0
# department_name_Dry Goods & Pasta 0 replaceBY 0
# department_name_Fall Wine, Beer, & Spirits 0 replaceBY 0
# department_name_Father's Day 0 replaceBY 0
# department_name_Fill the Grill 0 replaceBY 0
# department_name_Find it at Target 0 replaceBY 0
# department_name_FitMarket 0 replaceBY 0
# department_name_Floral 0 replaceBY 0
# department_name_Fromagerie 0 replaceBY 0
# department_name_Frozen 0 replaceBY 0
# department_name_Game Day Specials 0 replaceBY 0
# department_name_Gifts for the Foodie 0 replaceBY 0
# department_name_Halloween 0 replaceBY 0
# department_name_Hanukkah 0 replaceBY 0
# department_name_Healthy Choices for 2016 0 replaceBY 0
# department_name_Healthy Eating 0 replaceBY 0
# department_name_Holiday 0 replaceBY 0
# department_name_Holiday Essentials 0 replaceBY 0
# department_name_Holiday Favorites 0 replaceBY 0
# department_name_Holiday Turkeys 0 replaceBY 0
# department_name_Holidays 0 replaceBY 0
# department_name_Household 0 replaceBY 0
# department_name_International 0 replaceBY 0
# department_name_Local 0 replaceBY 0
# department_name_Local Favorites 0 replaceBY 0
# department_name_Meat & Seafood 0 replaceBY 0
# department_name_Mother's Day 0 replaceBY 0
# department_name_New Year's Eve Extravaganza! 0 replaceBY 0
# department_name_Newly Added 0 replaceBY 0
# department_name_Olives, Gourmet Cheese, Salads 0 replaceBY 0
# department_name_Our Brands 0 replaceBY 0
# department_name_Pantry 0 replaceBY 0
# department_name_Personal Care 0 replaceBY 0
# department_name_Pets 0 replaceBY 0
# department_name_Popular 0 replaceBY 0
# department_name_Produce 0 replaceBY 0
# department_name_Reptile 0 replaceBY 0
# department_name_Rosh Hashanah & Yom Kippur 0 replaceBY 0
# department_name_Seasonal 0 replaceBY 0
# department_name_Small Animal 0 replaceBY 0
# department_name_Smoothie Central 0 replaceBY 0
# department_name_Snacks 0 replaceBY 0
# department_name_St. Patrick's Day Specials 0 replaceBY 0
# department_name_Star Wars 0 replaceBY 0
# department_name_Summer Drinks 0 replaceBY 0
# department_name_Super Bowl Party 0 replaceBY 0
# department_name_TEST SPECIAL AISLE 0 replaceBY 0
# department_name_Thanksgiving 0 replaceBY 0
# department_name_Thanksgiving A to Z 0 replaceBY 0
# department_name_Travel 0 replaceBY 0
# department_name_Valentine's Day Specials 0 replaceBY 0
# department_name_Valentine's- Made with Love! 0 replaceBY 0
# department_name_Vitamins & Supplements 0 replaceBY 0
#         quantity  ...  department_name_Vitamins & Supplements
# 0       0.387167  ...                                       0
# 1       0.262070  ...                                       0
# 2       0.181991  ...                                       0
# 3       0.181991  ...                                       0
# 4       0.262070  ...                                       0
# 5       0.262070  ...                                       0
# 6       0.387167  ...                                       0
# 7       0.387167  ...                                       0
# 8       0.387167  ...                                       0
# 9       0.490489  ...                                       0
# 10      0.524696  ...                                       0
# 11      0.387167  ...                                       0
# 12      0.413816  ...                                       0
# 13      0.290871  ...                                       0
# 14      0.181991  ...                                       0
# 15      0.290871  ...                                       0
# 16      0.387167  ...                                       0
# 17      0.119344  ...                                       0
# 18      0.181991  ...                                       0
# 19      0.181991  ...                                       0
# 20      0.119344  ...                                       0
# 21      0.226963  ...                                       0
# 22      0.226963  ...                                       0
# 23      0.315290  ...                                       0
# 24      0.262070  ...                                       0
# 25      0.262070  ...                                       0
# 26      0.119344  ...                                       0
# 27      0.119344  ...                                       0
# 28      0.181991  ...                                       0
# 29      0.181991  ...                                       0
# ...          ...  ...                                     ...
# 180336  0.119344  ...                                       0
# 180337  0.119344  ...                                       0
# 180338  0.119344  ...                                       0
# 180339  0.262070  ...                                       0
# 180340  0.119344  ...                                       0
# 180341  0.119344  ...                                       0
# 180342  0.119344  ...                                       0
# 180343  0.119344  ...                                       0
# 180344  0.119344  ...                                       0
# 180345  0.119344  ...                                       0
# 180346  0.226963  ...                                       0
# 180347  0.262070  ...                                       0
# 180348  0.119344  ...                                       0
# 180349  0.226963  ...                                       0
# 180350  0.262070  ...                                       0
# 180351  0.119344  ...                                       0
# 180352  0.119344  ...                                       0
# 180353  0.119344  ...                                       0
# 180354  0.119344  ...                                       0
# 180355  0.119344  ...                                       0
# 180356  0.119344  ...                                       0
# 180357  0.119344  ...                                       0
# 180358  0.119344  ...                                       0
# 180359  0.119344  ...                                       0
# 180360  0.119344  ...                                       0
# 180361  0.226963  ...                                       0
# 180362  0.119344  ...                                       0
# 180363  0.181991  ...                                       0
# 180364  0.262070  ...                                       0
# 180365  0.315290  ...                                       0
#
# [2040286 rows x 79 columns]

# %%
#df_full_date  = df_full_date.dropna()
df_full_date.head()
# Out:
#    quantity  ...  department_name_Vitamins & Supplements
# 0  0.387167  ...                                       0
# 1  0.262070  ...                                       0
# 2  0.181991  ...                                       0
# 3  0.181991  ...                                       0
# 4  0.262070  ...                                       0
#
# [5 rows x 79 columns]

# %%
coldate
# Out:
# ['shopping_started_at', 'shopping_ended_at']

# %%
util_feature.pd_col_study_summary(df_full_date,colname = colnum)
# Out:
#    Col_name  Col_id  Nb_Unique    MinVal  MaxVal  MedianVal  MeanVal   StdDev
# 0  quantity       0        210 -0.168868     1.0   0.264708  0.32578  0.23716

# %%
coldate1 = 'shopping_started_at'
coldate2 = 'shopping_ended_at'

# %%
df_full_date[coldate1] = df_full_date[coldate1].apply( lambda x : util_date.datestring_todatetime(x) )

# %%
df_full_date.dtypes
# Out:
# quantity                                                 float64
# fulfillment_model                                          int64
# shopping_started_at                               datetime64[ns]
# department_name_25% OFF Supplements 8/14-8/16              uint8
# department_name_4th of July                                uint8
# department_name_Academy Awards                             uint8
# department_name_Alcohol                                    uint8
# department_name_All It Takes to Bake!                      uint8
# department_name_Aquatics                                   uint8
# department_name_BBQ Favorites                              uint8
# department_name_Babies                                     uint8
# department_name_Bakery                                     uint8
# department_name_Beverages                                  uint8
# department_name_Bi-Rite Creamery                           uint8
# department_name_Bi-Rite's Winter Favorites!                uint8
# department_name_Breakfast                                  uint8
# department_name_Bulk                                       uint8
# department_name_Burning Man Essentials                     uint8
# department_name_Business Items                             uint8
# department_name_Buyers' Picks                              uint8
# department_name_Canned Goods                               uint8
# department_name_Cat                                        uint8
# department_name_Cheese                                     uint8
# department_name_Christmas & NYE Menu                       uint8
# department_name_Dairy & Eggs                               uint8
# department_name_Deli                                       uint8
# department_name_Dog                                        uint8
# department_name_Dry Goods & Pasta                          uint8
# department_name_Fall Wine, Beer, & Spirits                 uint8
# department_name_Father's Day                               uint8
#                                                        ...
# department_name_Local                                      uint8
# department_name_Local Favorites                            uint8
# department_name_Meat & Seafood                             uint8
# department_name_Mother's Day                               uint8
# department_name_New Year's Eve Extravaganza!               uint8
# department_name_Newly Added                                uint8
# department_name_Olives, Gourmet Cheese, Salads             uint8
# department_name_Our Brands                                 uint8
# department_name_Pantry                                     uint8
# department_name_Personal Care                              uint8
# department_name_Pets                                       uint8
# department_name_Popular                                    uint8
# department_name_Produce                                    uint8
# department_name_Reptile                                    uint8
# department_name_Rosh Hashanah & Yom Kippur                 uint8
# department_name_Seasonal                                   uint8
# department_name_Small Animal                               uint8
# department_name_Smoothie Central                           uint8
# department_name_Snacks                                     uint8
# department_name_St. Patrick's Day Specials                 uint8
# department_name_Star Wars                                  uint8
# department_name_Summer Drinks                              uint8
# department_name_Super Bowl Party                           uint8
# department_name_TEST SPECIAL AISLE                         uint8
# department_name_Thanksgiving                               uint8
# department_name_Thanksgiving A to Z                        uint8
# department_name_Travel                                     uint8
# department_name_Valentine's Day Specials                   uint8
# department_name_Valentine's- Made with Love!               uint8
# department_name_Vitamins & Supplements                     uint8
# Length: 79, dtype: object

# %%
#df['shopping_started_quarter'] = util_date.datetime_get_quarter(index = 0,df=df,coldate= coldate)
#df['shopping_ended_quarter'] = Get_Quarter(1)


df_full_date['shopping_started_quarter'] = df_full_date[coldate1].apply( lambda x : util_date.datetime_quarter(x) )

# %%
df_full_date[[ 'shopping_started_quarter', 'shopping_started_at']].head(3)
# Out:
#    shopping_started_quarter shopping_started_at
# 0                         4 2015-09-01 07:04:33
# 1                         4 2015-09-01 07:04:33
# 2                         4 2015-09-01 07:04:33

# %%
df_full_date['shopping_started_week'] =  df_full_date[coldate1].apply( lambda x : util_date.datetime_weekday(x) )
#df['shopping_ended_week'] = Get_week(1)

# %%
df_full_date['shopping_started_hour'] = df_full_date[coldate1].apply( lambda x : util_date.datetime_tointhour(x) )
#df_full_date['shopping_ended_hour'] = Get_hour(1)

# %%
df_full_date['shopping_started_milisec'] = df_full_date[coldate1].apply( lambda x : util_date.datetime_to_milisec(x) )
#df_full_date['shopping_ended_milisec'] = Get_milisec(1)

# %%
df_full_date['shopping_started_at'] = df_full_date[coldate1].apply( lambda x : util_date.datetime_toint(x) )
#df_full_date['shopping_ended_at'] = Get_int(1)

# %%
util_plot.plot_col_distribution(df_full_date)
# Out:
# ('NaN count:', 0, 'Unique count:', 210)
# ('Max:', 1.0, 'Min:', -0.16886841542178238)
# ('Median', 0.11934382103684889, 'Mean:', 0.14607722471613296, 'Std:', 0.057108434876363176)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 1.0, 'Mean:', 0.6501882579207032, 'Std:', 0.4769103554995873)
# ('NaN count:', 0, 'Unique count:', 83)
# ('Max:', 20151122, 'Min:', 20150901)
# ('Median', 20151013.0, 'Mean:', 20151009.618137848, 'Std:', 77.64397484392369)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00025829712108988643, 'Std:', 0.016069548957177455)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00047346303410404227, 'Std:', 0.021754054032740184)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0020021702839699927, 'Std:', 0.04470080086669566)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.023646194700154784, 'Std:', 0.15194424035269372)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0006322643002010502, 'Std:', 0.02513691592172241)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 2.156560403786528e-05, 'Std:', 0.004643828050497538)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 3.136815132780404e-05, 'Std:', 0.0056006399069112025)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.005881038246598761, 'Std:', 0.07646209280251753)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.03303360411236464, 'Std:', 0.1787243271401859)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.07255012287493028, 'Std:', 0.25939661244080037)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0007552862686897818, 'Std:', 0.02747209149923082)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00015340986508754164, 'Std:', 0.012384923516147991)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.019500207323875182, 'Std:', 0.1382749045857601)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00657113757581045, 'Std:', 0.08079577790188187)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00019850158262125996, 'Std:', 0.014087660548968265)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00028966527241769044, 'Std:', 0.017017090422503066)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 6.861783102957134e-05, 'Std:', 0.008283303847067073)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.024729866303057513, 'Std:', 0.15530067615979787)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0014223496117701147, 'Std:', 0.037687219761505526)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0008645846709725989, 'Std:', 0.029391106891699707)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 9.802547289938763e-06, 'Std:', 0.0031308866475817025)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.1015367453386437, 'Std:', 0.30203813448748335)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.03932929010932781, 'Std:', 0.19437720300699907)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0010934741501926692, 'Std:', 0.0330496363743314)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.020619168097021693, 'Std:', 0.14210565788879928)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 3.528917024377955e-05, 'Std:', 0.005940364039201897)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00015978152082600185, 'Std:', 0.012639461645639992)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0007484244855868246, 'Std:', 0.027347108556046634)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0006356951917525288, 'Std:', 0.02520498132067769)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00290694539883134, 'Std:', 0.05383767330856298)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00047199265201055147, 'Std:', 0.021720264154632175)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00012988375159168861, 'Std:', 0.0113959151366953)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.043604671109834604, 'Std:', 0.20421386771528952)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0002700601778378129, 'Std:', 0.016431288608571123)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00010047610972187233, 'Std:', 0.010023273630568383)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.001276781784514524, 'Std:', 0.03570926508329814)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 7.744012359051623e-05, 'Std:', 0.00879966627877299)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0010072117340412079, 'Std:', 0.031720612518739574)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00042739106184133007, 'Std:', 0.02066902026515984)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 1.1763056747926517e-05, 'Std:', 0.0034297111217160055)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0006523595221454247, 'Std:', 0.02553299726235232)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00018134712486386713, 'Std:', 0.013465297549039561)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 5.39140100946632e-06, 'Std:', 0.0023219328031322257)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0009170282989737714, 'Std:', 0.030268586985068402)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.02692171587708782, 'Std:', 0.16185467892934444)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.008517433340227792, 'Std:', 0.09189606449420219)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 9.312419925441825e-05, 'Std:', 0.009649638705046499)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00010096623708636926, 'Std:', 0.010047688435920866)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.03155292934421939, 'Std:', 0.17480658452706546)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 1.1763056747926517e-05, 'Std:', 0.0034297111217160055)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 7.694999622601929e-05, 'Std:', 0.008771777181626314)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00041121685881293114, 'Std:', 0.020274312799894327)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.000214185658285162, 'Std:', 0.014633515735767221)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0005955047478637799, 'Std:', 0.024395698841374713)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.05081885578786503, 'Std:', 0.21962763870760263)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.016793233889758594, 'Std:', 0.12849599676753534)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0028579326623816466, 'Std:', 0.05338318914488847)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.2317449612456293, 'Std:', 0.42194695659868287)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.11598913093556491, 'Std:', 0.3202118867880725)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 8.822292560944888e-06, 'Std:', 0.002970221326450078)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 2.9407641869816292e-05, 'Std:', 0.0054228015877787715)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 5.881528373963258e-06, 'Std:', 0.0024251791236086545)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 3.8720061795258115e-05, 'Std:', 0.006222424170054038)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.008548311364191099, 'Std:', 0.09206105439876267)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.08606979609721382, 'Std:', 0.28046708594235764)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00039504265578453216, 'Std:', 0.01987175374959751)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 7.84203783195101e-06, 'Std:', 0.0028003528946176867)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 5.881528373963258e-06, 'Std:', 0.0024251791236086545)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00021908693193013135, 'Std:', 0.014799963947469222)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 8.675254351595806e-05, 'Std:', 0.009313700527295882)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.006842178008377257, 'Std:', 0.08243398940048297)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.0011635623633157312, 'Std:', 0.034091179004874655)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 1.1763056747926517e-05, 'Std:', 0.0034297111217160055)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 8.577228878696418e-05, 'Std:', 0.009260935800524719)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 0.00014311719043310595, 'Std:', 0.011962303620244242)
# ('NaN count:', 0, 'Unique count:', 2)
# ('Max:', 1, 'Min:', 0)
# ('Median', 0.0, 'Mean:', 5.293375536566932e-05, 'Std:', 0.007275366202687823)
# ('NaN count:', 0, 'Unique count:', 1)
# ('Max:', 4, 'Min:', 4)
# ('Median', 4.0, 'Mean:', 4.0, 'Std:', 0.0)
# ('NaN count:', 0, 'Unique count:', 7)
# ('Max:', 6, 'Min:', 0)
# ('Median', 2.0, 'Mean:', 2.6716769119623427, 'Std:', 2.0181482208491603)
# ('NaN count:', 0, 'Unique count:', 114338)
# ('Max:', 20151122220933, 'Min:', 20150901070356)
# ('Median', 20151013202757.5, 'Mean:', 20151009754212.336, 'Std:', 77644055.96604908)
# ('NaN count:', 0, 'Unique count:', 114338)
# ('Max:', 1448230173.0, 'Min:', 1441091036.0)
# ('Median', 1444768057.5, 'Mean:', 1444780152.100756, 'Std:', 2045670.745334814)

# %%
#data_imputer = Imputer()
#df_full_date = data_imputer.fit_transform(df_full_date)
df_full_date.head()
# Out:
#    quantity  fulfillment_model  ...  shopping_started_hour  shopping_started_milisec
# 0  0.387167                  0  ...         20150901070433              1.441091e+09
# 1  0.262070                  0  ...         20150901070433              1.441091e+09
# 2  0.181991                  0  ...         20150901070433              1.441091e+09
# 3  0.181991                  0  ...         20150901070433              1.441091e+09
# 4  0.262070                  0  ...         20150901070433              1.441091e+09
#
# [5 rows x 83 columns]

# %%
df_data = df_full_date.drop('fulfillment_model', axis = 1)
df_label = df_full_date['fulfillment_model']
train_X, val_X, train_y, val_y = train_test_split(df_data,df_label,test_size = 0.4,
                                                 random_state=42)

# %%
logReg = LogisticRegression()
model = logReg.fit(train_X, train_y)

# %%
pred = logReg.predict(val_X)

# %%
def classification_report(y_true, y_pred):
  return util_model.classification_report(y_true, y_pred).split('\n')

# %%
confusion_matrix(val_y,pred)
# Out:
# array([[     0, 286052],
#        [     0, 530063]])

# %%
classification_report(pred,val_y)
# Out:
# ['              precision    recall  f1-score   support',
#  '',
#  '           0       0.00      0.00      0.00         0',
#  '           1       1.00      0.65      0.79    816115',
#  '',
#  '    accuracy                           0.65    816115',
#  '   macro avg       0.50      0.32      0.39    816115',
#  'weighted avg       1.00      0.65      0.79    816115',
#  '']

# %%
DecTree = DecisionTreeClassifier()
model = DecTree.fit(train_X, train_y)

# %%
pred = DecTree.predict(val_X)

# %%
confusion_matrix(val_y,pred)
# Out:
# array([[199933,  86119],
#        [ 97840, 432223]])

# %%
classification_report(pred,val_y)
# Out:
# ['              precision    recall  f1-score   support',
#  '',
#  '           0       0.70      0.67      0.68    297773',
#  '           1       0.82      0.83      0.82    518342',
#  '',
#  '    accuracy                           0.77    816115',
#  '   macro avg       0.76      0.75      0.75    816115',
#  'weighted avg       0.77      0.77      0.77    816115',
#  '']

# %%
pd.DataFrame(cross_val_score(estimator= DecTree , X = train_X, y = train_y,scoring = 'accuracy',cv=5), columns = ['accuarcy_per_cv'])
# Out:
#    accuarcy_per_cv
# 0         0.768195
# 1         0.766627
# 2         0.769227
# 3         0.767250
# 4         0.766461

# %%
#Using RandomForestClassifier to get the Features Importance.
RandomForest = RandomForestClassifier()
model = RandomForest.fit(train_X, train_y)

# %%
df_importance= pd.DataFrame(model.feature_importances_, columns = ['Importance'])

# %%
df_importance['Feature'] = df_data.columns

# %%
df_importance = df_importance.sort_values(by = 'Importance',ascending=False)
df_importance = df_importance.head()

# %%
#Features Importance
plt.Figure(figsize=(25,25))
plt.bar(df_importance['Feature'], df_importance['Importance'], align='center', alpha=0.5,)
plt.gcf().set_size_inches(16, 17)
